# %%
import requests
from bs4 import BeautifulSoup
import csv
import pandas as pd

# %%
for i in range(0 , 10000, 20):
    src = requests.get("https://english.ahram.org.eg/AllCategory/5/25/Arts%20&%20Culture/Visual%20Art/"+str(i)+".aspx").content
    #print(src)
    soup= BeautifulSoup(src , "lxml")
    
    article_title=[]
    articles_title= soup.find_all("div",{"class":"col-md-12 col-lg-12 mar-top-outer"})
    
    for r in range(len(articles_title)):
        article_title.append(articles_title[r].text)
        
    Articles_Scraper = pd.DataFrame({'Article Title': article_title,})

    #Articles_Scraper['Article Title'].str.strip()

    Articles_Scraper['Category']='Art'
    print("iteration number",str(i),", Done")
    magic=pd.read_csv('magic.csv')
    magic = pd.concat([Articles_Scraper,magic])
    
    magic = magic.drop(columns=['Unnamed: 0'])
    magic.to_csv('magic.csv')
    print(magic.shape)
# Out:
# iteration number 0 , Done
# (8704, 2)
# iteration number 20 , Done
# (8724, 2)
# iteration number 40 , Done
# (8744, 2)
# iteration number 60 , Done
# (8764, 2)
# iteration number 80 , Done
# (8784, 2)
# iteration number 100 , Done
# (8804, 2)
# iteration number 120 , Done
# (8824, 2)
# iteration number 140 , Done
# (8844, 2)
# iteration number 160 , Done
# (8864, 2)
# iteration number 180 , Done
# (8884, 2)
# iteration number 200 , Done
# (8904, 2)
# iteration number 220 , Done
# (8924, 2)
# iteration number 240 , Done
# (8944, 2)
# iteration number 260 , Done
# (8964, 2)
# iteration number 280 , Done
# (8984, 2)
# iteration number 300 , Done
# (9004, 2)
# iteration number 320 , Done
# (9024, 2)
# iteration number 340 , Done
# (9044, 2)
# iteration number 360 , Done
# (9064, 2)
# iteration number 380 , Done
# (9084, 2)
# iteration number 400 , Done
# (9104, 2)
# iteration number 420 , Done
# (9124, 2)
# iteration number 440 , Done
# (9144, 2)
# iteration number 460 , Done
# (9164, 2)
# iteration number 480 , Done
# (9184, 2)
# iteration number 500 , Done
# (9204, 2)
# iteration number 520 , Done
# (9224, 2)
# iteration number 540 , Done
# (9244, 2)
# iteration number 560 , Done
# (9264, 2)
# iteration number 580 , Done
# (9284, 2)
# iteration number 600 , Done
# (9304, 2)
# iteration number 620 , Done
# (9324, 2)
# iteration number 640 , Done
# (9344, 2)
# iteration number 660 , Done
# (9364, 2)
# iteration number 680 , Done
# (9384, 2)
# iteration number 700 , Done
# (9404, 2)
# iteration number 720 , Done
# (9424, 2)
# iteration number 740 , Done
# (9444, 2)
# iteration number 760 , Done
# (9464, 2)
# iteration number 780 , Done
# (9484, 2)
# iteration number 800 , Done
# (9504, 2)
# iteration number 820 , Done
# (9524, 2)
# iteration number 840 , Done
# (9544, 2)
# iteration number 860 , Done
# (9564, 2)
# iteration number 880 , Done
# (9584, 2)
# iteration number 900 , Done
# (9604, 2)
# iteration number 920 , Done
# (9624, 2)
# iteration number 940 , Done
# (9644, 2)
# iteration number 960 , Done
# (9664, 2)
# iteration number 980 , Done
# (9684, 2)
# iteration number 1000 , Done
# (9704, 2)
# iteration number 1020 , Done
# (9724, 2)
# iteration number 1040 , Done
# (9744, 2)
# iteration number 1060 , Done
# (9764, 2)
# iteration number 1080 , Done
# (9784, 2)
# iteration number 1100 , Done
# (9804, 2)
# iteration number 1120 , Done
# (9824, 2)
# iteration number 1140 , Done
# (9844, 2)
# iteration number 1160 , Done
# (9864, 2)
# iteration number 1180 , Done
# (9884, 2)
# iteration number 1200 , Done
# (9904, 2)
# iteration number 1220 , Done
# (9924, 2)
# iteration number 1240 , Done
# (9944, 2)
# iteration number 1260 , Done
# (9964, 2)
# iteration number 1280 , Done
# (9984, 2)
# iteration number 1300 , Done
# (10004, 2)
# iteration number 1320 , Done
# (10024, 2)
# iteration number 1340 , Done
# (10044, 2)
# iteration number 1360 , Done
# (10064, 2)
# iteration number 1380 , Done
# (10084, 2)
# iteration number 1400 , Done
# (10104, 2)
# iteration number 1420 , Done
# (10124, 2)
# iteration number 1440 , Done
# (10144, 2)
# iteration number 1460 , Done
# (10164, 2)
# iteration number 1480 , Done
# (10184, 2)
# iteration number 1500 , Done
# (10204, 2)
# iteration number 1520 , Done
# (10224, 2)
# iteration number 1540 , Done
# (10244, 2)
# iteration number 1560 , Done
# (10264, 2)
# iteration number 1580 , Done
# (10284, 2)
# iteration number 1600 , Done
# (10304, 2)
# iteration number 1620 , Done
# (10324, 2)
# iteration number 1640 , Done
# (10344, 2)
# iteration number 1660 , Done
# (10364, 2)
# iteration number 1680 , Done
# (10384, 2)
# iteration number 1700 , Done
# (10404, 2)
# iteration number 1720 , Done
# (10424, 2)
# iteration number 1740 , Done
# (10444, 2)
# iteration number 1760 , Done
# (10457, 2)
# iteration number 1780 , Done
# (10457, 2)
# iteration number 1800 , Done
# (10457, 2)
# iteration number 1820 , Done
# (10457, 2)
# iteration number 1840 , Done
# (10457, 2)
# iteration number 1860 , Done
# (10457, 2)
# iteration number 1880 , Done
# (10457, 2)
# iteration number 1900 , Done
# (10457, 2)
# iteration number 1920 , Done
# (10457, 2)
# iteration number 1940 , Done
# (10457, 2)
# iteration number 1960 , Done
# (10457, 2)
# iteration number 1980 , Done
# (10457, 2)
# iteration number 2000 , Done
# (10457, 2)
# iteration number 2020 , Done
# (10457, 2)
# iteration number 2040 , Done
# (10457, 2)
# iteration number 2060 , Done
# (10457, 2)
# iteration number 2080 , Done
# (10457, 2)
# iteration number 2100 , Done
# (10457, 2)
# iteration number 2120 , Done
# (10457, 2)
# iteration number 2140 , Done
# (10457, 2)
# iteration number 2160 , Done
# (10457, 2)
# iteration number 2180 , Done
# (10457, 2)
# iteration number 2200 , Done
# (10457, 2)
# iteration number 2220 , Done
# (10457, 2)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-3033a3112fff> in <module>
#       1 for i in range(0 , 10000, 20):
# ----> 2     src = requests.get("https://english.ahram.org.eg/AllCategory/5/25/Arts%20&%20Culture/Visual%20Art/"+str(i)+".aspx").content
#       3     #print(src)
#       4     soup= BeautifulSoup(src , "lxml")
#       5
#
# ~\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     527         }
#     528         send_kwargs.update(settings)
# --> 529         resp = self.send(prep, **send_kwargs)
#     530
#     531         return resp
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     643
#     644         # Send the request
# --> 645         r = adapter.send(request, **kwargs)
#     646
#     647         # Total elapsed time of the request (approximately)
#
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438         try:
#     439             if not chunked:
# --> 440                 resp = conn.urlopen(
#     441                     method=request.method,
#     442                     url=url,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     701
#     702             # Make the request on the httplib connection object.
# --> 703             httplib_response = self._make_request(
#     704                 conn,
#     705                 method,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     447                     # Python 3 (including for exceptions like SystemExit).
#     448                     # Otherwise it looks like a bug in the code.
# --> 449                     six.raise_from(e, None)
#     450         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     442                 # Python 3
#     443                 try:
# --> 444                     httplib_response = conn.getresponse()
#     445                 except BaseException as e:
#     446                     # Remove the TypeError from the exception chain in
#
# ~\anaconda3\lib\http\client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# ~\anaconda3\lib\http\client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# ~\anaconda3\lib\http\client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~\anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~\anaconda3\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
for i in range(20 , 10000, 20):
    #src = requests.get("https://english.ahram.org.eg/AllCategory/6/55/Sports/World/"+str(i)+".aspx").content
    src = requests.get("https://english.ahram.org.eg/AllCategory/3/12/Business/Economy/"+str(i)+".aspx").content

    soup= BeautifulSoup(src , "lxml")
    
    article_title=[]
    articles_title= soup.find_all("div",{"class":"col-md-12 col-lg-12 mar-top-outer"})
    
    for r in range(len(articles_title)):
        article_title.append(articles_title[r].text)
        
    Articles_Scraper = pd.DataFrame({'Article Title': article_title,})

    Articles_Scraper['Article Title'].str.strip()

    Articles_Scraper['Category']='economy'
    print("iteration number",str(i),", Done")
    economy=pd.read_csv('economy.csv')
    economy = pd.concat([Articles_Scraper,economy])
    
    economy = economy.drop(columns=['Unnamed: 0'])
    economy.to_csv('economy_final.csv')
    print(economy.shape)
