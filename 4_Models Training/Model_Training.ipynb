# %%
import pandas as pd
import numpy as np
import nltk
#for model-building
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report, f1_score, accuracy_score, confusion_matrix
from sklearn.metrics import roc_curve, auc, roc_auc_score
# bag of words
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
#for word embedding
#import gensim
#from gensim.models import Word2Vec

# %%
#reading the cleaned dataset
df_start = pd.read_csv('final_processed_df.csv').drop(columns=['Unnamed: 0'])
print(df_start.columns)

#SPLITTING THE TRAINING DATASET INTO TRAIN AND TEST
X_train, X_test, y_train, y_test = train_test_split(df_start["Final_Text"],df_start["Category"],test_size=0.2,shuffle=True)
X_train.head()
# Out:
# Index(['Final_Text', 'Category'], dtype='object')
# 10283    fleabag succession chernobyl win top golden gl...
# 13067        egypt aim final arabtec housing deal midmarch
# 7271     cinegouna extends submission deadline film pos...
# 3551     art alert gypsy jazz project perform live cair...
# 13479    cyprus gas field produce 8 bcm year pipeline e...
# Name: Final_Text, dtype: object

# %%
#Word2Vec
# Word2Vec runs on tokenized sentences
X_train_tok= [nltk.word_tokenize(i) for i in X_train]  
X_test_tok= [nltk.word_tokenize(i) for i in X_test]
X_train_tok
# Out:
# [['fleabag',
#   'succession',
#   'chernobyl',
#   'win',
#   'top',
#   'golden',
#   'globe',
#   'egyptianamerican',
#   'actor',
#   'ramy',
#   'youssef',
#   'farewell',
#   'star',
#   'awkwafina',
#   'among',
#   'people',
#   'color',
#   'win'],
#  ['egypt', 'aim', 'final', 'arabtec', 'housing', 'deal', 'midmarch'],
#  ['cinegouna',
#   'extends',
#   'submission',
#   'deadline',
#   'film',
#   'postproduction',
#   'filmmaker',
#   'film',
#   'postproduction',
#   'still',
#   'opportunity',
#   'compete',
#   'elgouna',
#   'film',
#   'festivalâ\x80\x99s',
#   'cash',
#   'award'],
#  ['art',
#   'alert',
#   'gypsy',
#   'jazz',
#   'project',
#   'perform',
#   'live',
#   'cairo',
#   'bandâ\x80\x99s',
#   'music',
#   'influenced',
#   'renowned',
#   'jazz',
#   'artist',
#   'django',
#   'reinhardt',
#   'stephane',
#   'grappelli'],
#  ['cyprus',
#   'gas',
#   'field',
#   'produce',
#   '8',
#   'bcm',
#   'year',
#   'pipeline',
#   'egypt'],
#  ['egypt',
#   'sisi',
#   'transfer',
#   'agricultural',
#   'development',
#   'credit',
#   'bank',
#   'cbe',
#   'supervision',
#   'newly',
#   'named',
#   'egyptian',
#   'agricultural',
#   'bank',
#   'run',
#   'jointstock',
#   'entity',
#   'stateowned',
#   'capital'],
#  ['ramos',
#   'injured',
#   'amid',
#   'doubt',
#   'real',
#   'madrid',
#   'future',
#   'ramos',
#   'available',
#   'madrid',
#   'game',
#   'sevilla',
#   'sunday'],
#  ['vardy',
#   'double',
#   'deal',
#   'fresh',
#   'blow',
#   'arsenal',
#   'champion',
#   'league',
#   'hope'],
#  ['manchester',
#   'city',
#   'need',
#   'spend',
#   'january',
#   'compete',
#   'title',
#   'say',
#   'neville'],
#  ['video',
#   'short',
#   'film',
#   'woman',
#   'egyptian',
#   'cinema',
#   'ciff',
#   '41st',
#   'cairo',
#   'international',
#   'film',
#   'festival',
#   'posted',
#   'short',
#   'film',
#   'role',
#   'woman',
#   'egyptian',
#   'cinema'],
#  ['man', 'damaged', 'banksy', 'art', 'u', 'get', 'probation'],
#  ['evertons', 'mina', 'sidelined', 'several', 'week', 'thigh', 'injury'],
#  ['egypt', 'pm', 'witness', 'signing', 'agreement', 'mercedesbenz'],
#  ['flying',
#   'carpet',
#   '28',
#   'may',
#   'cairo',
#   'symphony',
#   'orchestra',
#   'conducted',
#   'hisham',
#   'gabr',
#   'acclaimed',
#   'given',
#   'standing',
#   'ovation',
#   'performance',
#   'two',
#   'masterpiece',
#   'classical',
#   'music',
#   'elgar',
#   'cello',
#   'concerto',
#   'korsakovs',
#   'scheherazade'],
#  ['egypt', 'china', 'discus', 'cooperation', 'manufacture', 'electric', 'car'],
#  ['palestinian',
#   'movie',
#   'close',
#   'european',
#   'film',
#   'festival',
#   'beirut',
#   'directed',
#   'mai',
#   'masri',
#   'palestinian',
#   'film',
#   '3000',
#   'night',
#   'close',
#   'european',
#   'film',
#   'festival',
#   'run',
#   'beirut',
#   '6',
#   'february'],
#  ['egypt', 'stock', 'slightly', 'tuesday', 'foreigner', 'net', 'buyer'],
#  ['shakira',
#   'release',
#   'baby',
#   'toy',
#   'fisherprice',
#   'shakira',
#   'partnering',
#   'fisherprice',
#   'launch',
#   'line',
#   'baby',
#   'toy',
#   'well',
#   'web',
#   'series',
#   'mom'],
#  ['big', 'short', 'awarded', 'producer', 'guild', 'award'],
#  ['art',
#   'alert',
#   'bassem',
#   'yousriâ\x80\x99s',
#   'latest',
#   'video',
#   'work',
#   'screen',
#   'zawya',
#   'bassem',
#   'yousris',
#   'film',
#   'wardrobe',
#   'man',
#   'screened',
#   'one',
#   'day',
#   'zawya',
#   'followup',
#   'discussion'],
#  ['gasping',
#   'rawabet',
#   'theatre',
#   'three',
#   'consecutive',
#   'evening',
#   'play',
#   'ben',
#   'elton',
#   'directed',
#   'leila',
#   'saad',
#   'performed',
#   'rawabet',
#   'theatre'],
#  ['qatar',
#   'world',
#   'cup',
#   'ticket',
#   'sale',
#   'open',
#   'lowest',
#   '70',
#   'globally',
#   'fan',
#   'start',
#   'registering',
#   'buy',
#   'qatar',
#   'world',
#   'cup',
#   'ticket',
#   'wednesday',
#   'price',
#   'visitor',
#   'starting',
#   'around',
#   '70',
#   'onethird',
#   'cheaper',
#   'tournament',
#   'russia'],
#  ['saudi',
#   'energy',
#   'minister',
#   'saudi',
#   'aramcos',
#   'public',
#   'offering',
#   'soon'],
#  ['egypt',
#   'plan',
#   'reduce',
#   'debttogdp',
#   'ratio',
#   '90',
#   'end',
#   'fy202122',
#   'egypt',
#   'aim',
#   'lower',
#   'overall',
#   'debttogdp',
#   'ratio',
#   '90',
#   'percent',
#   'june',
#   '2022',
#   '85',
#   'percent',
#   'coming',
#   'three',
#   'year',
#   '108',
#   'percent',
#   'recorded',
#   'june',
#   '2017',
#   'minister',
#   'finance',
#   'mohamed',
#   'maait',
#   'announced',
#   'tuesday'],
#  ['poland', 'restarts', 'procedure', 'extradite', 'polanski', 'u'],
#  ['egypt', 'issue', '25', '3', 'billion', 'eurobonds', 'january', 'minister'],
#  ['first',
#   'phase',
#   'siemens',
#   'power',
#   'plant',
#   'project',
#   'egypt',
#   'inaugurated',
#   'february'],
#  ['64',
#   'egypt',
#   'business',
#   'optimistic',
#   'future',
#   'market',
#   'hsbc',
#   'report'],
#  ['liverpool',
#   'coach',
#   'klopp',
#   'bristle',
#   'keanes',
#   'sloppy',
#   'criticism',
#   'arsenal',
#   'win'],
#  ['china',
#   'overtakes',
#   'u',
#   'globe',
#   'biggest',
#   'trading',
#   'nation',
#   'china',
#   'saw',
#   'trade',
#   'surplus',
#   '2597',
#   'billion',
#   '2013'],
#  ['chelsea', 'fan', 'savour', 'hazard', 'magic', 'much', 'longer'],
#  ['match',
#   'fact',
#   'borussia',
#   'dortmund',
#   'v',
#   'sevilla',
#   'uefa',
#   'champion',
#   'league',
#   'ahram',
#   'online',
#   'provided',
#   'live',
#   'score',
#   'coverage',
#   'tuesday',
#   'match',
#   'borussia',
#   'dortmund',
#   'sevilla',
#   '2nd',
#   'leg',
#   'uefa',
#   'champion',
#   'league',
#   'round',
#   '16'],
#  ['bale', 'left', 'zidane', 'man', 'city', 'test'],
#  ['boosting',
#   'cooperation',
#   'trade',
#   'exchange',
#   'african',
#   'country',
#   'top',
#   'egyptâ\x80\x99s',
#   'priority',
#   'trade',
#   'minister',
#   'meeting',
#   'tackled',
#   'mean',
#   'providing',
#   'service',
#   '50',
#   'million',
#   'african',
#   'woman',
#   'speak',
#   'platform',
#   'â\x80\x94',
#   'first',
#   'platform',
#   'group',
#   '50',
#   'million',
#   'woman',
#   'trade',
#   'industrial',
#   'domain',
#   '38',
#   'african',
#   'country'],
#  ['drama',
#   'music',
#   'fest',
#   'present',
#   'live',
#   'orchestral',
#   'rendition',
#   'egyptian',
#   'film',
#   'soundtrack',
#   'ahmed',
#   'atef',
#   'main',
#   'dynamo',
#   'behind',
#   'unprecedented',
#   'musical',
#   'event',
#   'egypt',
#   'explains',
#   'aim',
#   'festival',
#   'scheduled',
#   '6',
#   'june',
#   'share',
#   'hope',
#   'future',
#   'development'],
#  ['egx',
#   'loses',
#   'egp',
#   '2456',
#   'sunday',
#   'suffers',
#   'worst',
#   'day',
#   'since',
#   'february'],
#  ['juves', 'de', 'sciglio', 'thigh', 'injury', 'least', '10', 'day'],
#  ['stadium',
#   'issue',
#   'could',
#   'hamper',
#   'oman',
#   'world',
#   'cup',
#   '2022',
#   'hope'],
#  ['egypt', 'budget', 'deficit', '6', 'first', '8', 'month', '201314'],
#  ['egypt',
#   'finance',
#   'ministry',
#   'auction',
#   'tbills',
#   'worth',
#   'egp',
#   '185bn'],
#  ['ac', 'milan', 'drawn', 'away', 'shamrock', 'rover', 'europa', 'league'],
#  ['egyptian', 'iconic', 'singer', 'actress', 'shadia', 'pass', 'away', '86'],
#  ['snapshot', 'instagrabbing', 'palestinian', 'landscape'],
#  ['fourth',
#   'edition',
#   'vision',
#   'cairo',
#   'egyptian',
#   'short',
#   'film',
#   'festival',
#   'go',
#   'online',
#   'fourth',
#   'edition',
#   'festival',
#   'screen',
#   '123',
#   'film',
#   '50',
#   'take',
#   'part',
#   'official',
#   'competition'],
#  ['injured',
#   'ibrahimovic',
#   'withdraws',
#   'sweden',
#   'squad',
#   'zlatan',
#   'ibrahimovic',
#   'pulled',
#   'sweden',
#   'squad',
#   'upcoming',
#   'world',
#   'cup',
#   'qualifier',
#   'achilles',
#   'tendon',
#   'injury',
#   'country',
#   'football',
#   'federation',
#   'announced',
#   'saturday'],
#  ['egypt', 'germany', 'mull', 'technological', 'cooperation', 'environment'],
#  ['intention',
#   'impose',
#   'new',
#   'tax',
#   'egypt',
#   'finance',
#   'minister',
#   'finance',
#   'minister',
#   'mohamed',
#   'maait',
#   'also',
#   'said',
#   'egypt',
#   'set',
#   'provide',
#   'stimulus',
#   'package',
#   'private',
#   'sector',
#   'sake',
#   'maximising',
#   'role',
#   'development',
#   'process',
#   'country',
#   'witnessing'],
#  ['alec',
#   'baldwin',
#   'sued',
#   'family',
#   'cinematographer',
#   'killed',
#   'â\x80\x98rustâ\x80\x99',
#   'set',
#   'family',
#   'cinematographer',
#   'shot',
#   'killed',
#   'set',
#   'film',
#   'â\x80\x9crustâ\x80\x9d',
#   'suing',
#   'alec',
#   'baldwin',
#   'movie',
#   'producer',
#   'wrongful',
#   'death',
#   'attorney',
#   'said',
#   'tuesday'],
#  ['egyptian',
#   'pound',
#   'strengthens',
#   'threeyear',
#   'high',
#   'trade',
#   'egp',
#   '1566',
#   'per',
#   '1',
#   'egp',
#   'last',
#   'traded',
#   'strong',
#   'nov',
#   '17',
#   '2016',
#   'six',
#   'day',
#   'signed',
#   '12',
#   'billion',
#   'threeyear',
#   'loan',
#   'agreement',
#   'imf'],
#  ['uaeâ\x80\x99s',
#   'gmis2021',
#   'concludes',
#   'calling',
#   'global',
#   'cooperation',
#   'industrial',
#   'manufacturing',
#   'recovery',
#   'fourth',
#   'edition',
#   'global',
#   'manufacturing',
#   'industrialisation',
#   'summit',
#   'gmis2021',
#   'concluded',
#   'saturday',
#   'asserting',
#   'importance',
#   'cooperation',
#   'unified',
#   'effort',
#   'sake',
#   'sectorâ\x80\x99s',
#   'growth',
#   'pandemic',
#   'recovery'],
#  ['final',
#   'countdown',
#   '6th',
#   'sharm',
#   'elsheikh',
#   'intl',
#   'theatre',
#   'festival',
#   'youth',
#   'sixth',
#   'edition',
#   'sharm',
#   'elsheikh',
#   'international',
#   'theatre',
#   'festival',
#   'youth',
#   'sitfy',
#   'held',
#   '6',
#   '11',
#   'november'],
#  ['egypt', 'finance', 'ministry', 'auction', 'egp', '25', 'bln', 'tbonds'],
#  ['challenge',
#   'opportunity',
#   'arab',
#   'film',
#   'industry',
#   'berlinale',
#   'european',
#   'film',
#   'market',
#   'focus'],
#  ['india',
#   'set',
#   'become',
#   'menas',
#   'top',
#   'trading',
#   'partner',
#   '2030',
#   'report',
#   'manufacture',
#   'chemical',
#   'mineral',
#   'fuel',
#   'fastestgrowing',
#   'export',
#   'egypt',
#   'india',
#   '2013',
#   '2030',
#   'according',
#   'hsbc',
#   'forecast',
#   'report'],
#  ['russia', 'agrees', 'partially', 'lift', 'ban', 'egyptian', 'potato'],
#  ['football', 'know', 'odd', 'sight', 'bundesliga', 'comeback'],
#  ['culture',
#   'event',
#   'pick',
#   'weekend',
#   'sure',
#   'weekend',
#   'standup',
#   'comedy',
#   'african',
#   'music',
#   'opera',
#   'short',
#   'film',
#   'among',
#   'exciting',
#   'thing',
#   'inside',
#   'outside',
#   'capital',
#   'thursday',
#   'sunday',
#   '36',
#   'may'],
#  ['â\x80\x98wall',
#   'loveâ\x80\x99',
#   'heals',
#   'paris',
#   'neighbourhood',
#   'scarred',
#   'terrorism',
#   'horrific',
#   'shooting',
#   'brought',
#   'unusually',
#   'high',
#   'number',
#   'foreign',
#   'visitor',
#   'littleknown',
#   'corner',
#   'northeastern',
#   'paris'],
#  ['egyptâ\x80\x99s',
#   'nonoil',
#   'pmi',
#   '504',
#   'point',
#   'september',
#   'highest',
#   'since',
#   'july',
#   '2019',
#   'improved',
#   'commercial',
#   'condition',
#   'egyptâ\x80\x99s',
#   'nonoilproducing',
#   'sector',
#   'reflected',
#   'indexâ\x80\x99s',
#   'latest',
#   'reading',
#   'due',
#   'improvement',
#   'consumer',
#   'demand',
#   'export',
#   'sale',
#   'said',
#   'elsaid'],
#  ['un',
#   'call',
#   'young',
#   'volunteer',
#   'elsawy',
#   'culturewheel',
#   'celebration',
#   'egyptâ\x80\x99s',
#   'youth',
#   'spirit',
#   'volunteerism',
#   'present',
#   'opportunity',
#   'egyptian',
#   'youth'],
#  ['creative',
#   'city',
#   'symposium',
#   'negotiating',
#   'downtown',
#   'cairo',
#   'cluster',
#   'cairo',
#   'lab',
#   'urban',
#   'study',
#   'training',
#   'environmental',
#   'research',
#   'organised',
#   'twoday',
#   'symposium',
#   'titled',
#   'creative',
#   'city',
#   'reframing',
#   'downtown',
#   'held',
#   'aucâ\x80\x99s',
#   'premise',
#   'tahrir',
#   '31',
#   'october',
#   '1',
#   'november'],
#  ['atletico', 'madrid', 'costa', 'suffers', 'slipped', 'disc'],
#  ['egypt',
#   'integrated',
#   'diagnostics',
#   'target',
#   '600',
#   'mln',
#   'valuation',
#   'uk',
#   'float'],
#  ['jimenez',
#   'savour',
#   'fantastic',
#   'first',
#   'goal',
#   'wolf',
#   'since',
#   'horror',
#   'injury',
#   'wolf',
#   'striker',
#   'raul',
#   'jimenez',
#   'said',
#   'felt',
#   'fantastic',
#   'score',
#   'first',
#   'premier',
#   'league',
#   'goal',
#   'almost',
#   'year',
#   'recovering',
#   'careerthreatening',
#   'head',
#   'injury'],
#  ['somalia',
#   'national',
#   'theatre',
#   'reopens',
#   '20',
#   'year',
#   'somalia',
#   'national',
#   'theatre',
#   'reopened',
#   'warravaged',
#   'capital',
#   'mogadishu',
#   'first',
#   'time',
#   '20',
#   'year',
#   'monday',
#   'president',
#   'voicing',
#   'hope',
#   'would',
#   'mark',
#   'watershed',
#   'long',
#   'quest',
#   'peace'],
#  ['pogba',
#   'included',
#   'man',
#   'utd',
#   'squad',
#   'preseason',
#   'tour',
#   'amid',
#   'transfer',
#   'talk'],
#  ['italy',
#   'serie',
#   'result',
#   'scorer',
#   '34th',
#   'matchday',
#   'follow',
#   'ahram',
#   'onlines',
#   'coverage',
#   'italy',
#   'serie',
#   'match',
#   '2729',
#   'april'],
#  ['egyptian',
#   'public',
#   'bank',
#   'issue',
#   'dollar',
#   'certificate',
#   'citizen',
#   'abroad'],
#  ['egypt',
#   'stock',
#   'red',
#   'sluggish',
#   'start',
#   'week',
#   'main',
#   'index',
#   'listed',
#   'heavyweight',
#   'fell',
#   'sunday',
#   'due',
#   'institutional',
#   'sale',
#   'leading',
#   'telecom',
#   'real',
#   'estate',
#   'share',
#   'slipping'],
#  ['egypt',
#   'm2',
#   'money',
#   'supply',
#   'rise',
#   '186',
#   'pct',
#   'june',
#   'central',
#   'bank'],
#  ['egypt',
#   'boxoffice',
#   'race',
#   'heat',
#   'welad',
#   'rizk',
#   'elfil',
#   'elazraq',
#   'sequel',
#   'summer',
#   'season',
#   'coming',
#   'close',
#   'majority',
#   'cinemagoers',
#   'going',
#   'back',
#   'school'],
#  ['egypt',
#   'trade',
#   'balance',
#   'deficit',
#   'hit',
#   '387',
#   'bln',
#   'april',
#   '2019',
#   'capmas'],
#  ['trailer',
#   'eid',
#   'elfitr',
#   'film',
#   'across',
#   'egypt',
#   'cinema',
#   'ahram',
#   'online',
#   'brings',
#   'selection',
#   'film',
#   'released',
#   'cinema',
#   'across',
#   'egypt',
#   'eid',
#   'elfitr'],
#  ['question',
#   'culture',
#   'ongoing',
#   'struggle',
#   'one',
#   'consequence',
#   'revolution',
#   'going',
#   'limited',
#   'freedom',
#   'expression',
#   'creativity',
#   'egypt',
#   'islamist',
#   'sideline',
#   'liberal',
#   'ball',
#   'miltarys',
#   'court'],
#  ['planet', 'ape', 'climb', 'top', 'u', 'box', 'office', 'chart'],
#  ['egypt',
#   'attracts',
#   '31',
#   'billion',
#   'foreign',
#   'investment',
#   'domestic',
#   'debt',
#   'since',
#   'flotation',
#   'deputy',
#   'finance',
#   'minister'],
#  ['tottenham',
#   'maintain',
#   'social',
#   'distancing',
#   'rule',
#   'player',
#   'resume',
#   'training'],
#  ['yield', 'steady', 'egypt', 'oneyear', 'usd', 'tbill', 'auction'],
#  ['man',
#   'city',
#   'verdict',
#   'european',
#   'ban',
#   'expected',
#   'week',
#   'july',
#   '13'],
#  ['eib',
#   'creates',
#   'climate',
#   'advisory',
#   'council',
#   'step',
#   'climate',
#   'action',
#   'eib',
#   'groupâ\x80\x99s',
#   'climate',
#   'bank',
#   'roadmap',
#   'set',
#   'detail',
#   'eib',
#   'group',
#   'aim',
#   'support',
#   'objective',
#   'european',
#   'green',
#   'deal',
#   'sustainable',
#   'development',
#   'outside',
#   'european',
#   'union'],
#  ['egyptian',
#   'film',
#   'street',
#   'screen',
#   'character',
#   'hood',
#   'helwan',
#   'awardwinning',
#   'film',
#   'bara',
#   'fil',
#   'sharea',
#   'made',
#   'egypt',
#   'premiere',
#   'art',
#   'house',
#   'cinema',
#   'zawya',
#   'last',
#   'january'],
#  ['egypt',
#   'stock',
#   'decline',
#   '189',
#   'pct',
#   'following',
#   'end',
#   'eid',
#   'aladha',
#   'break'],
#  ['waiting',
#   'bill',
#   'egypt',
#   'anticipated',
#   'hike',
#   'electricity',
#   'price',
#   'ghada',
#   'raafat',
#   'sound',
#   'expert',
#   'opinion',
#   'announced',
#   'increase',
#   'electricity',
#   'price'],
#  ['art',
#   'alert',
#   'shakespeare',
#   'measure',
#   'measure',
#   'cairo',
#   'falaki',
#   'theatre',
#   'directed',
#   'waleed',
#   'hammad',
#   'play',
#   'run',
#   'five',
#   'day'],
#  ['manchester', 'united', 'draw', 'club', 'brugge', 'europa', 'league'],
#  ['newcastle',
#   'return',
#   'training',
#   'virus',
#   'outbreak',
#   'premier',
#   'league',
#   'club'],
#  ['italy',
#   'playersâ\x80\x99',
#   'union',
#   'say',
#   'returning',
#   'training',
#   'would',
#   'dangerous'],
#  ['liverpool', 'stun', 'barcelona', 'reach', 'final', '40', 'comeback', 'win'],
#  ['spain', 'la', 'liga', 'say', 'ready', 'turn', 'eu', 'city', 'psg', 'case'],
#  ['unemployment',
#   'egypt',
#   'drop',
#   'lowest',
#   'level',
#   'since',
#   '2010',
#   'unemployment',
#   'dropped',
#   'lowest',
#   'level',
#   'since',
#   '2010',
#   'structural',
#   'problem',
#   'job',
#   'market',
#   'persist'],
#  ['cairo',
#   'film',
#   'society',
#   'festival',
#   'nominee',
#   'upcoming',
#   'edition',
#   'announced',
#   'cairo',
#   'film',
#   'society',
#   'festivalâ\x80\x99s',
#   'board',
#   'shortlisted',
#   '12',
#   'favourite',
#   'selection',
#   'total',
#   '52',
#   'egyptian',
#   'film',
#   'released',
#   '2020',
#   '2021',
#   'compete',
#   'upcoming',
#   'edition',
#   'launching',
#   'cairo',
#   'opera',
#   'houseâ\x80\x99s',
#   'creativity',
#   'centre',
#   '29',
#   'january'],
#  ['people',
#   'story',
#   'inspire',
#   'egyptian',
#   'scriptwriter',
#   'mariam',
#   'naoum',
#   'ahram',
#   'online',
#   'speaks',
#   'scriptwriter',
#   'mariam',
#   'naoum',
#   'latest',
#   'tv',
#   'drama',
#   'series',
#   'taht',
#   'el',
#   'saytara',
#   'scheduled',
#   'air',
#   'ramadan'],
#  ['juventus', 'win', 'eighth', 'serie', 'title', 'row'],
#  ['west', 'ham', 'lingard', 'lifted', 'london', 'high', 'life'],
#  ['brussels', 'gang', 'film', 'pulled', 'french', 'cinema', 'paris', 'attack'],
#  ['cairo',
#   'international',
#   'festival',
#   'experimental',
#   'theatre',
#   'return',
#   'cairo',
#   'international',
#   'festival',
#   'experimental',
#   'theatre',
#   'scheduled',
#   'return',
#   'threeyear',
#   'hiatus',
#   'ministry',
#   'culture',
#   'announced',
#   'week'],
#  ['afraid',
#   'forget',
#   'face',
#   'represents',
#   'egypt',
#   'toronto',
#   'arab',
#   'film',
#   'festival',
#   'festival',
#   'second',
#   'edition',
#   'take',
#   'place',
#   'virtually',
#   'last',
#   'week',
#   'may'],
#  ['burnley', 'winger', 'lennon', 'undergoes', 'knee', 'surgery'],
#  ['mohamed',
#   'abla',
#   'art',
#   'change',
#   'two',
#   'week',
#   'artist',
#   'dedicated',
#   'voice',
#   'chanting',
#   'time',
#   'raising',
#   'political',
#   'awareness',
#   'among',
#   'eclectic',
#   'crowd',
#   'adding',
#   'dash',
#   'colour',
#   'tahrir',
#   'square'],
#  ['solskjaer',
#   'defends',
#   'decision',
#   'rest',
#   'ronaldo',
#   'everton',
#   'slip',
#   'ole',
#   'gunnar',
#   'solskjaer',
#   'said',
#   'regret',
#   'resting',
#   'cristiano',
#   'ronaldo',
#   'manchester',
#   'united',
#   'let',
#   'two',
#   'premier',
#   'league',
#   'point',
#   'slip',
#   'away',
#   'old',
#   'trafford',
#   'everton',
#   'emerged',
#   '11',
#   'draw',
#   'saturday'],
#  ['egyptian',
#   'painter',
#   'abla',
#   'insert',
#   'peace',
#   'paris',
#   'mural',
#   'delhi',
#   'street',
#   'art',
#   'project',
#   'taking',
#   'idea',
#   'french',
#   'artist',
#   'jean',
#   'jullien',
#   'createed',
#   'sign',
#   'peace',
#   'paris',
#   'friday',
#   'mohamed',
#   'abla',
#   'show',
#   'solidarity',
#   'victim',
#   'paris',
#   'attack'],
#  ['10th',
#   'malmã¶',
#   'arab',
#   'film',
#   'festival',
#   'take',
#   'place',
#   'october',
#   '2020',
#   'planned',
#   'scandinavia',
#   'best',
#   'known',
#   'festival',
#   'dedicated',
#   'arab',
#   'film',
#   'hold',
#   'upcoming',
#   'edition',
#   'october',
#   'schedule'],
#  ['superb', 'neuer', 'denies', 'bremen', 'bayern', 'munich', 'held', 'home'],
#  ['egypt', 'aim', 'cut', 'fuel', 'import', '10', 'pct', 'consumption', '2019'],
#  ['egypt',
#   'stock',
#   'close',
#   'red',
#   'brief',
#   'sunday',
#   'morning',
#   'rally',
#   'friday',
#   'push',
#   'global',
#   'market',
#   'fuel',
#   'initial',
#   'egx30',
#   'rally',
#   'uncertainty',
#   'coming',
#   'week',
#   'performance',
#   'hamper',
#   'investor',
#   'appetite'],
#  ['seasonal',
#   'concern',
#   'opening',
#   'new',
#   'orchestral',
#   'season',
#   'cairo',
#   'symphony',
#   'orchestra',
#   'announced',
#   'first',
#   'four',
#   'concert',
#   'new',
#   'season',
#   'audience',
#   'still',
#   'awaits',
#   'complete',
#   'programme'],
#  ['director',
#   'kamla',
#   'abu',
#   'zekri',
#   'break',
#   'silence',
#   'ramadan',
#   'series',
#   'attribution',
#   'kamla',
#   'abu',
#   'zekri',
#   'took',
#   'facebook',
#   'express',
#   'dismay',
#   'director',
#   'sameh',
#   'abdelaziz',
#   'crediting',
#   'first',
#   'eight',
#   'episode',
#   'television',
#   'series',
#   'zay',
#   'elshams',
#   'directed'],
#  ['norwich', 'hold', 'tottenham', 'fourgoal', 'thriller'],
#  ['everything',
#   'need',
#   'know',
#   'week',
#   '2',
#   '2016',
#   'dcaf',
#   'festival',
#   'ahram',
#   'online',
#   'take',
#   'indepth',
#   'look',
#   'second',
#   'week',
#   'yearâ\x80\x99s',
#   'downtown',
#   'contemporary',
#   'art',
#   'festival',
#   'dcaf',
#   'run',
#   '22',
#   'april'],
#  ['cheerful', 'madonna', 'shrug', 'controversy', 'malawi'],
#  ['laporte', 'fit', 'face', 'real', 'madrid', 'say', 'guardiola'],
#  ['egyptian',
#   'soprano',
#   'rita',
#   'ashkar',
#   'perform',
#   'german',
#   'opera',
#   'production',
#   'ashkar',
#   'sing',
#   'benjamin',
#   'britten',
#   'opera',
#   'albert',
#   'herring',
#   'produced',
#   'university',
#   'music',
#   'detmold'],
#  ['greek', 'bank', 'reopen', 'monday', 'tsipras', 'eye', 'new', 'start'],
#  ['egypt',
#   'say',
#   'resolved',
#   'land',
#   'dispute',
#   'dubai',
#   'alfuttaim',
#   'al',
#   'futtaim',
#   'group',
#   'pay',
#   'egypt',
#   'government',
#   'million',
#   'dollar',
#   'order',
#   'resolve',
#   'land',
#   'dispute',
#   'concerning',
#   'cairo',
#   'festival',
#   'city'],
#  ['jota', 'cap', 'liverpool', 'fightback', 'sink', 'blade'],
#  ['central',
#   'bank',
#   'egypt',
#   'expected',
#   'keep',
#   'interest',
#   'rate',
#   'unchanged',
#   'central',
#   'bank',
#   'monetary',
#   'policy',
#   'committee',
#   'set',
#   'meet',
#   'thursday',
#   'decide',
#   'interest',
#   'rate'],
#  ['art',
#   'alert',
#   'oscar',
#   'nominated',
#   'film',
#   'brooklyn',
#   'screen',
#   'cairo',
#   'open',
#   'discussion',
#   'follow',
#   'one',
#   'screening',
#   'cairo',
#   'arthouse',
#   'cinema',
#   'zawya'],
#  ['kaka',
#   'urge',
#   'neymar',
#   'stay',
#   'psg',
#   'lead',
#   'champion',
#   'league',
#   'push'],
#  ['ecb', 'extends', 'emergency', 'liquidity', 'greek', 'bank'],
#  ['arab',
#   'idol',
#   'contestant',
#   'missing',
#   'syria',
#   'syrian',
#   'contestant',
#   'season',
#   'arab',
#   'idol',
#   'singing',
#   'competition',
#   'mbc',
#   'missing',
#   'three',
#   'week',
#   'trip',
#   'hometown',
#   'aleppo'],
#  ['depay', 'dumfries', 'send', 'netherlands', 'euro', '2020', 'knockout'],
#  ['ifc',
#   'egyptâ\x80\x99s',
#   'fintech',
#   'association',
#   'cooperate',
#   'support',
#   'sectorâ\x80\x99s',
#   'entrepreneur',
#   'ifc',
#   'also',
#   'help',
#   'association',
#   'create',
#   'vibrant',
#   'streamlined',
#   'fintech',
#   'sector',
#   'sharing',
#   'global',
#   'experience',
#   'supporting',
#   'knowledge',
#   'exchange',
#   'around',
#   'policy',
#   'dialogue'],
#  ['arteta',
#   'confident',
#   'arsenal',
#   'project',
#   'moving',
#   'right',
#   'direction',
#   'arsenal',
#   'fa',
#   'cup',
#   'defence',
#   'ended',
#   'southampton',
#   'fourth',
#   'round',
#   'europa',
#   'league',
#   'hope',
#   'silverware',
#   'season'],
#  ['domestic',
#   'liquidity',
#   'reached',
#   'egp',
#   '4140',
#   'trillion',
#   'end',
#   'january',
#   'central',
#   'bank',
#   'egypt'],
#  ['centamin',
#   'earnings',
#   'jump',
#   'strong',
#   'gold',
#   'price',
#   'higher',
#   'egypt',
#   'mine',
#   'output',
#   'gold',
#   'price',
#   'surged',
#   '30',
#   'far',
#   'year',
#   'supported',
#   'mainly',
#   'lower',
#   'interest',
#   'rate',
#   'widespread',
#   'stimulus',
#   'measure',
#   'global',
#   'central',
#   'bank',
#   'ease',
#   'economic',
#   'blow',
#   'pandemic'],
#  ['kuwaiti',
#   'arab',
#   'fund',
#   'economic',
#   'social',
#   'development',
#   'looking',
#   'forward',
#   'financing',
#   'project',
#   'egypt',
#   'chairman'],
#  ['benzema',
#   'down',
#   'celta',
#   'real',
#   'madrid',
#   'close',
#   'atletico',
#   'result',
#   'increase',
#   'pressure',
#   'atletico',
#   'ahead',
#   'game',
#   'hand',
#   'home',
#   'alaves',
#   'sunday',
#   'madrid',
#   'climb',
#   'second',
#   'least',
#   'thirdplaced',
#   'barcelona',
#   'play',
#   'real',
#   'sociedad',
#   'also',
#   'sunday'],
#  ['naseer',
#   'shamma',
#   'el',
#   'sawy',
#   'culturewheel',
#   'new',
#   'year',
#   'eve',
#   'naseer',
#   'shamma',
#   'celebrate',
#   'new',
#   'year',
#   '2012',
#   'fan',
#   'el',
#   'sawy',
#   'culturewheel',
#   'next',
#   'saturday',
#   '31',
#   'december'],
#  ['egypt', 'partner', 'cnn', 'promote', 'egyptian', 'tourism'],
#  ['ebrd',
#   'partner',
#   'acquire',
#   'egyptâ\x80\x99s',
#   'adwia',
#   'pharmaceutical',
#   'total',
#   'worth',
#   'deal',
#   '250',
#   'million'],
#  ['egypt',
#   'within',
#   'prima',
#   'ballerina',
#   'magda',
#   'saleh',
#   'career',
#   'gilded',
#   'year',
#   'renowned',
#   'ballerina',
#   'graduate',
#   'bolshoi',
#   'ballet',
#   'academy',
#   'cairo',
#   'academy',
#   'art',
#   'former',
#   'dean',
#   'higher',
#   'institute',
#   'ballet',
#   'founding',
#   'director',
#   'new',
#   'cairo',
#   'opera',
#   'house',
#   'magda',
#   'saleh',
#   'talk',
#   'career'],
#  ['lampard',
#   'bemoans',
#   'chelseas',
#   'injury',
#   'crisis',
#   'ahead',
#   'liverpool',
#   'cup',
#   'tie'],
#  ['guangzhou',
#   'defender',
#   'zhang',
#   'miss',
#   'rest',
#   'asian',
#   'champion',
#   'league',
#   '31yearold',
#   'china',
#   'international',
#   'sustained',
#   'injury',
#   'guangzhouâ\x80\x99s',
#   '31',
#   'loss',
#   'vissel',
#   'kobe',
#   'last',
#   'week'],
#  ['centamin',
#   'q3',
#   'egypt',
#   'gold',
#   'mine',
#   'production',
#   'exceeds',
#   'target',
#   'sukkari',
#   'flagship',
#   'gold',
#   'mine',
#   'production',
#   '7',
#   'q4',
#   'yearonyear',
#   'total',
#   '2013',
#   'output',
#   'beat',
#   'guidance',
#   '11',
#   'despite',
#   'expansion',
#   'work',
#   'political',
#   'turmoil',
#   'egypt'],
#  ['germany',
#   'mueller',
#   'set',
#   'miss',
#   'hungary',
#   'showdown',
#   'missing',
#   'training'],
#  ['xavi', 'talk', 'take', 'barcelona', 'job', 'club'],
#  ['chinese', 'dissident', 'artist', 'ai', 'weiwei', 'major', 'london', 'show'],
#  ['egypt',
#   'receives',
#   'second',
#   '500',
#   'million',
#   'tranche',
#   'african',
#   'development',
#   'bank',
#   'loan'],
#  ['marco', 'verratti', 'sprained', 'ankle', 'psg', 'say'],
#  ['200',
#   'meter',
#   'palestinian',
#   'director',
#   'ameen',
#   'nayfeh',
#   'scoop',
#   '3',
#   'award',
#   'el',
#   'gouna',
#   'festival',
#   'film',
#   'brought',
#   'ali',
#   'suliman',
#   'el',
#   'gouna',
#   'star',
#   'best',
#   'actor',
#   'received',
#   'audience',
#   'award',
#   'film',
#   'exemplifying',
#   'humanitarian',
#   'theme',
#   'fipresci',
#   'award'],
#  ['cairoâ\x80\x99s',
#   'el',
#   'sawy',
#   'culturewheel',
#   'launch',
#   'mobilephone',
#   'film',
#   'competition',
#   'deadline',
#   'submitting',
#   'work',
#   '4',
#   'may'],
#  ['germany',
#   'bundesliga',
#   'result',
#   'scorer',
#   '8th',
#   'matchday',
#   'follow',
#   'ahram',
#   'onlines',
#   'coverage',
#   'germany',
#   'bundesliga',
#   'match',
#   '20212022',
#   'season',
#   '1517',
#   'october'],
#  ['cairo',
#   'international',
#   'film',
#   'festival',
#   'host',
#   '16',
#   'premiere',
#   '42nd',
#   'edition',
#   'president',
#   'festival',
#   'mohamed',
#   'hefzy',
#   'proud',
#   'programming',
#   'team',
#   'worked',
#   'hard',
#   'debut',
#   'selection',
#   'anticipated',
#   'film',
#   'year',
#   'massive',
#   'audience',
#   'film',
#   'critic',
#   'cinephiles',
#   'cairo'],
#  ['lady',
#   'gaga',
#   'caught',
#   'bad',
#   'romance',
#   'china',
#   'meeting',
#   'dalai',
#   'lama'],
#  ['karachi', 'artist', 'reclaim', 'city', 'wall', 'hate', 'graffiti'],
#  ['mummy',
#   'square',
#   'egypt',
#   'film',
#   'diff',
#   'trailer',
#   '13th',
#   'edition',
#   'dubai',
#   'international',
#   'film',
#   'festival',
#   'see',
#   'nine',
#   'participating',
#   'entry',
#   'egypt',
#   'spanning',
#   'short',
#   'film',
#   'feature',
#   'documentary'],
#  ['goaladdict', 'lewandowski', 'level', 'ronaldo', 'messi'],
#  ['art',
#   'agenda',
#   'summer',
#   'exhibition',
#   'cairo',
#   'summer',
#   'kick',
#   'number',
#   'diverse',
#   'visual',
#   'art',
#   'exhibition',
#   'cairo',
#   'ahram',
#   'online',
#   'offer',
#   'recommendation'],
#  ['manchester',
#   'city',
#   'soon',
#   'score',
#   '10',
#   'say',
#   'watfords',
#   'ben',
#   'foster'],
#  ['egypt',
#   'could',
#   'cut',
#   'tax',
#   'stock',
#   'exchange',
#   'investor',
#   'bourse',
#   'chairman'],
#  ['momentum',
#   'revolution',
#   'flashback',
#   'safarkhan',
#   'gallery',
#   'artist',
#   'marwa',
#   'adel',
#   'look',
#   'back',
#   'day',
#   'colour',
#   'tahrir',
#   'square',
#   'uprising',
#   'long',
#   'revolutionary',
#   'fire',
#   'cooled'],
#  ['winner',
#   'egypt',
#   '13th',
#   'national',
#   'theatre',
#   'festival',
#   'festival',
#   'took',
#   'place',
#   '20',
#   'december',
#   '2020',
#   '2',
#   'january',
#   '2021'],
#  ['cairo',
#   'rendered',
#   'unfamiliar',
#   'townhouses',
#   'new',
#   'sound',
#   'light',
#   'installation',
#   'magdi',
#   'mostafas',
#   'sound',
#   'light',
#   'installation',
#   'translates',
#   'cairo',
#   'pulsing',
#   'electric',
#   'current',
#   'poetically',
#   'subversively',
#   'capture',
#   'energy',
#   'chaos',
#   'melancholia'],
#  ['asia',
#   'market',
#   'mixed',
#   'investor',
#   'eye',
#   'omicron',
#   'chinese',
#   'tech',
#   'woe',
#   'asian',
#   'market',
#   'mixed',
#   'trading',
#   'monday',
#   'tracking',
#   'uncertainty',
#   'omicron',
#   'variant',
#   'coronavirus',
#   'well',
#   'disappointing',
#   'u',
#   'job',
#   'data',
#   'struggling',
#   'chinese',
#   'tech',
#   'firm'],
#  ['egyptian',
#   'musician',
#   'really',
#   'talented',
#   'free',
#   'open',
#   'chad',
#   'smith',
#   'lead',
#   'crosspollination',
#   'culture',
#   'cairo',
#   'american',
#   'drummer',
#   'chad',
#   'smith',
#   'member',
#   'famed',
#   'rock',
#   'band',
#   'red',
#   'hot',
#   'chili',
#   'pepper',
#   'gave',
#   'special',
#   'performance',
#   'egyptian',
#   'musician',
#   '13',
#   'march',
#   'elsawy',
#   'culturewheel',
#   'cairo'],
#  ['culture',
#   'essential',
#   'weapon',
#   'extremist',
#   'thinking',
#   'hend',
#   'sabry',
#   'tunisian',
#   'official',
#   'honor',
#   'actress',
#   'hend',
#   'sabry',
#   'recent',
#   'visit',
#   'home',
#   'country'],
#  ['egypt', 'raise', 'supply', 'price', 'basic', 'crop', 'support', 'farmer'],
#  ['fan',
#   'egypt',
#   'beloved',
#   'mounir',
#   'fume',
#   'worstever',
#   'concert',
#   'vodafone',
#   'failure',
#   'mohamed',
#   'mounir',
#   'concert',
#   'attended',
#   '20000',
#   'organised',
#   'vodafone',
#   'star',
#   'cut',
#   'short',
#   'fan',
#   'voice',
#   'fury',
#   'long',
#   'way',
#   'home'],
#  ['egypt',
#   'receive',
#   '2',
#   'bln',
#   'international',
#   'finance',
#   'corporation',
#   'ifc',
#   'finance',
#   'focus',
#   'renewable',
#   'energy',
#   'field',
#   '2019'],
#  ['egypt',
#   'art',
#   'culture',
#   'recommended',
#   'event',
#   'week',
#   '2128',
#   'june',
#   'cairo',
#   'alexandria',
#   'brace',
#   'rich',
#   'cultural',
#   'week',
#   'include',
#   'ramadan',
#   'evening',
#   'unique',
#   'setting',
#   'fatimid',
#   'cairo',
#   'world',
#   'music',
#   'day',
#   'celebration',
#   'concert',
#   'egyptian',
#   'regional',
#   'musician',
#   'theatre',
#   'play'],
#  ['uefa',
#   'champion',
#   'league',
#   'quarterfinal',
#   'result',
#   'scorer',
#   'follow',
#   'ahram',
#   'onlines',
#   'coverage',
#   'uefa',
#   'champion',
#   'league',
#   'quarterfinal',
#   '917',
#   'april'],
#  ['egypt',
#   'adopts',
#   'integrated',
#   'plan',
#   'improve',
#   'cotton',
#   'textile',
#   'industry',
#   'public',
#   'business',
#   'sector',
#   'minister'],
#  ['brent', 'hit', '512year', 'low', '57', 'supply', 'glut', 'weighs'],
#  ['photo',
#   'street',
#   'carnival',
#   'project',
#   'brings',
#   'minority',
#   'culture',
#   'city',
#   'across',
#   'egypt',
#   'brainchild',
#   'alexandriabased',
#   'elmadina',
#   'foundation',
#   'street',
#   'carnival',
#   'streettheatre',
#   'initiative',
#   'aim',
#   'promote',
#   'diversity',
#   'break',
#   'stereotype'],
#  ['germany',
#   'bundesliga',
#   'result',
#   'scorer',
#   '28th',
#   'matchday',
#   'follow',
#   'ahram',
#   'onlines',
#   'coverage',
#   'germany',
#   'bundesliga',
#   'match',
#   '26',
#   'â\x80\x93',
#   '27',
#   'may'],
#  ['manchester',
#   'united',
#   'give',
#   'solskjaer',
#   'permanent',
#   'job',
#   'month',
#   'say',
#   'neville'],
#  ['van',
#   'damme',
#   'mourns',
#   'death',
#   'iconic',
#   'egyptian',
#   'actress',
#   'ragaa',
#   'elgiddawy'],
#  ['egypt',
#   'new',
#   'regulation',
#   'smes',
#   'positive',
#   'economy',
#   'negative',
#   'bank',
#   'moody'],
#  ['germany',
#   'bundesliga',
#   'result',
#   'scorer',
#   '9th',
#   'matchday',
#   'follow',
#   'ahram',
#   'onlines',
#   'coverage',
#   'germany',
#   'bundesliga',
#   'match',
#   '2729',
#   'november'],
#  ['putin',
#   'tchaikovsky',
#   'gay',
#   'russian',
#   'love',
#   'anyway',
#   'amid',
#   'fear',
#   'putin',
#   'taking',
#   'step',
#   'towards',
#   'cracking',
#   'gay',
#   'right',
#   'russian',
#   'president',
#   'say',
#   'tchaikovsky',
#   'gay',
#   'russian',
#   'love',
#   'anyway'],
#  ['second',
#   'zawya',
#   'short',
#   'film',
#   'festival',
#   'release',
#   'lineup',
#   'ahram',
#   'online',
#   'publishes',
#   'list',
#   'film',
#   'screening',
#   'part',
#   'second',
#   'zawyas',
#   'short',
#   'film',
#   'festival',
#   'scheduled',
#   'take',
#   'place',
#   '26',
#   '28',
#   'january'],
#  ['art',
#   'alert',
#   'ali',
#   'elhaggar',
#   'perform',
#   'alexandria',
#   'valentine',
#   'day',
#   'conductor',
#   'ahmed',
#   'amer',
#   'lead',
#   'orchestra',
#   'sabrin',
#   'elngeily',
#   'hasnaa',
#   'open',
#   'concert',
#   'thursday'],
#  ['oscarnominated',
#   'palestinian',
#   'short',
#   'ave',
#   'maria',
#   'released',
#   'across',
#   'u',
#   'cinema',
#   'basil',
#   'khalils',
#   'palestinian',
#   'short',
#   'film',
#   'ave',
#   'maria',
#   'released',
#   'across',
#   '400',
#   'cinema',
#   'theatre',
#   'u',
#   'film',
#   'distributor',
#   'arab',
#   'world',
#   'announced'],
#  ['smarting', 'barcelona', 'host', 'champion', 'league', 'chasing', 'getafe'],
#  ['busquets', 'test', 'positive', 'set', 'miss', 'spain', 'opener', 'euro'],
#  ['algeria',
#   'oran',
#   'arab',
#   'film',
#   'festival',
#   'promise',
#   'major',
#   'lineup',
#   'festival',
#   'run',
#   '20',
#   '27',
#   'july',
#   'showcasing',
#   'film',
#   '17',
#   'arab',
#   'country'],
#  ['reaction', 'chelseas', 'sacking', 'manager', 'frank', 'lampard'],
#  ['peles', 'last', 'brazil', 'jersey', 'sell', '30000', 'euro', 'italy'],
#  ['oil',
#   'slip',
#   'recent',
#   'gain',
#   'though',
#   'middle',
#   'east',
#   'tension',
#   'remain',
#   'high'],
#  ['lamprell', 'get', '365', 'mln', 'rig', 'contract', 'abu', 'dhabis', 'ndc'],
#  ['renowned',
#   'panflautist',
#   'gheorghe',
#   'zamfir',
#   'hold',
#   'cairo',
#   'concert',
#   'support',
#   'cancer',
#   'patient',
#   'romanian',
#   'musician',
#   'perform',
#   'charity',
#   'concert',
#   'fairmont',
#   'tower',
#   'hotel',
#   '18',
#   '19',
#   'january',
#   'several',
#   'egyptian',
#   'musical',
#   'movie',
#   'star',
#   'attendance'],
#  ['di', 'maria', 'point', 'prove', 'return', 'old', 'trafford', 'psg'],
#  ['egypt',
#   'strong',
#   'presence',
#   'london',
#   'shubbak',
#   'festival',
#   'contemporary',
#   'arab',
#   'culture',
#   'july',
#   'festival',
#   'held',
#   '1',
#   '16',
#   'july',
#   'feature',
#   'theatre',
#   'film',
#   'music',
#   'literature',
#   'visual',
#   'art',
#   'among',
#   'others'],
#  ['video',
#   'umm',
#   'kalthoum',
#   'revived',
#   'hologram',
#   'cairo',
#   'legendary',
#   'egyptian',
#   'singer',
#   'umm',
#   'kalthoum',
#   'sings',
#   '6',
#   'minute',
#   'launch',
#   'event',
#   'mbc',
#   'egypt',
#   'event',
#   'first',
#   'time',
#   'hologram',
#   'used',
#   'live',
#   'stage',
#   'middle',
#   'east'],
#  ['liverpool', 'klopp', 'say', 'manager', 'opinion', 'coronavirus', 'matter'],
#  ['brazil', 'beat', 'argentina', 'qualify', '2020', 'olympics'],
#  ['china',
#   'new',
#   'silk',
#   'road',
#   'promise',
#   'trade',
#   'rich',
#   'president',
#   'xi',
#   'helm'],
#  ['backing',
#   'egypt',
#   'economic',
#   'reform',
#   'programme',
#   'egypt',
#   'must',
#   'press',
#   'ahead',
#   'economic',
#   'reform',
#   'order',
#   'avoid',
#   'potential',
#   'risk',
#   'ahead'],
#  ['uk',
#   'police',
#   'officer',
#   'convicted',
#   'killing',
#   'exvilla',
#   'star',
#   'atkinson'],
#  ['italy',
#   'serie',
#   'result',
#   'scorer',
#   '30th',
#   'matchday',
#   'follow',
#   'ahram',
#   'onlines',
#   'coverage',
#   'italy',
#   'serie',
#   'match',
#   '45',
#   'july'],
#  ['video',
#   'pussy',
#   'riot',
#   'cathedral',
#   'video',
#   'banned',
#   'extremism',
#   'footage',
#   'pussy',
#   'riot',
#   'protest',
#   'president',
#   'vladimir',
#   'putin',
#   'altar',
#   'moscow',
#   'cathedral',
#   'banned',
#   'russia'],
#  ['art',
#   'alert',
#   'lecture',
#   'impressionism',
#   'postmodern',
#   'art',
#   'russian',
#   'cultural',
#   'centre',
#   'dokki',
#   'lecture',
#   'part',
#   'centre',
#   'celebration',
#   '75',
#   'year',
#   'diplomatic',
#   'tie',
#   'egypt',
#   'russia'],
#  ['relentless',
#   'manchester',
#   'city',
#   'go',
#   'five',
#   'clear',
#   'win',
#   'bournemouth'],
#  ['lampard', 'warns', 'chelsea', 'complacency', 'topfour', 'race'],
#  ['valverde',
#   'expects',
#   'fan',
#   'play',
#   'big',
#   'role',
#   'liverpool',
#   'despite',
#   'klopp',
#   'jibe'],
#  ['egypt',
#   'central',
#   'bank',
#   'pay',
#   '700',
#   'million',
#   'debt',
#   'paris',
#   'club',
#   'egypt',
#   'total',
#   'external',
#   'debt',
#   'stood',
#   '65',
#   'billion',
#   'december',
#   '2013',
#   '155',
#   'percent',
#   'gdp',
#   'compared',
#   '56',
#   'billion',
#   'december',
#   '2012',
#   '14',
#   'percent',
#   'gdp'],
#  ['villa',
#   'v',
#   'burnley',
#   'premier',
#   'league',
#   'match',
#   'covid',
#   'outbreak',
#   'aston',
#   'villa',
#   'home',
#   'match',
#   'burnley',
#   'postponed',
#   'due',
#   'coronavirus',
#   'outbreak',
#   'villa',
#   'squad',
#   'leaving',
#   'one',
#   'premier',
#   'league',
#   'fixture',
#   'schedule',
#   'saturday'],
#  ['egypt', 'gasc', 'draw', 'offer', 'seven', 'supplier', 'wheat', 'tender'],
#  ['egypt',
#   'serious',
#   'shortage',
#   'facemasks',
#   'glove',
#   'medical',
#   'supply',
#   'division',
#   'efcc',
#   'egypt',
#   'however',
#   'major',
#   'producer',
#   'sanitisers',
#   'alcohol',
#   'product',
#   'country',
#   'run',
#   'supply',
#   'official',
#   'said'],
#  ['manchester',
#   'united',
#   'bos',
#   'solskjaer',
#   'hoping',
#   'psg',
#   'repeat',
#   'barcelona'],
#  ['netflix',
#   'invested',
#   '160',
#   'million',
#   'robert',
#   'de',
#   'niros',
#   'film',
#   'irishman',
#   'director',
#   'martin',
#   'scorsese',
#   'netflix',
#   'use',
#   '117',
#   'different',
#   'filming',
#   'location',
#   'shoot',
#   '309',
#   'scene',
#   'robert',
#   'de',
#   'niros',
#   'crimedrama',
#   'irishmanpremiered',
#   'new',
#   'york',
#   'friday'],
#  ['lloris', 'urge', 'tottenham', 'learn', 'mistake'],
#  ['egypt',
#   'commercial',
#   'representation',
#   'service',
#   'provided',
#   '1100',
#   'export',
#   'opportunity',
#   '2019',
#   'trade',
#   'ministry'],
#  ['art',
#   'alert',
#   'dance',
#   'performance',
#   'inspired',
#   'life',
#   'salvador',
#   'dali',
#   'play',
#   'dance',
#   'performance',
#   'entitled',
#   'waheedâ\x80\x99an',
#   'brings',
#   'story',
#   'salvador',
#   'dali',
#   'stage'],
#  ['egypt', 'cbe', 'sell', '987', 'mn', 'egp', '143', 'regular', 'auction'],
#  ['match',
#   'fact',
#   'barcelona',
#   'v',
#   'dynamo',
#   'kyiv',
#   'uefa',
#   'champion',
#   'league',
#   'ahram',
#   'online',
#   'providing',
#   'live',
#   'score',
#   'coverage',
#   'wednesday',
#   'match',
#   'barcelona',
#   'dynamo',
#   'kyiv',
#   '3rd',
#   'round',
#   'uefa',
#   'champion',
#   'league',
#   'group',
#   'stage'],
#  ['ireland', 'basketball', 'ceo', 'apologizes', 'post', 'sterling'],
#  ['poet',
#   'poetry',
#   'anger',
#   'hold',
#   'first',
#   'conference',
#   'tuesday',
#   'wing',
#   'committee',
#   'culture',
#   'poet',
#   'movement',
#   'hold',
#   'conference',
#   'starting',
#   'tuesday',
#   'future',
#   'culture',
#   'egypt'],
#  ['cairo',
#   'el',
#   'genaina',
#   'theatre',
#   'kick',
#   'hayy',
#   'festival',
#   'musician',
#   'egypt',
#   'libya',
#   'festival',
#   'began',
#   '4',
#   'june',
#   'performance',
#   'instrumental',
#   'band',
#   'dokkan',
#   'libyan',
#   'singer',
#   'nasser',
#   'elmizdawi'],
#  ['art',
#   'alert',
#   'ayman',
#   'fanous',
#   'solo',
#   'guitar',
#   'bouzouki',
#   'concert',
#   'tahrir',
#   'cultural',
#   'center'],
#  ['brighton',
#   'player',
#   'collect',
#   '264000',
#   'pound',
#   'charity',
#   'hit',
#   'pandemic'],
#  ['young',
#   'arab',
#   'voice',
#   'take',
#   'place',
#   'tomorrow',
#   'elsawy',
#   'culturewheel',
#   'elsawy',
#   'culturewheel',
#   'host',
#   'young',
#   'arab',
#   'voice',
#   'tomorrow',
#   'tuesday',
#   '28',
#   'august',
#   'part',
#   'initiative',
#   'encourage',
#   'involvement',
#   'arab',
#   'youth'],
#  ['serie', 'sassuolo', 'say', 'player', 'start', 'training', 'monday'],
#  ['tunisian',
#   'film',
#   'son',
#   'scoop',
#   'three',
#   'award',
#   '41st',
#   'cairo',
#   'international',
#   'film',
#   'festival',
#   'film',
#   'best',
#   'arab',
#   'film',
#   'award',
#   'united',
#   'nation',
#   'population',
#   'fund',
#   'unfpa',
#   'award',
#   'salah',
#   'abu',
#   'seif',
#   'prize'],
#  ['egypt',
#   'govt',
#   'set',
#   'weekly',
#   'price',
#   'guide',
#   'fruit',
#   'vegetable',
#   'attempt',
#   'stabilise',
#   'egyptian',
#   'produce',
#   'price',
#   'government',
#   'unveils',
#   'first',
#   'price',
#   'guide',
#   'consumer',
#   'vendor'],
#  ['match',
#   'fact',
#   'bayern',
#   'munich',
#   'v',
#   'salzburg',
#   'uefa',
#   'champion',
#   'league',
#   'ahram',
#   'online',
#   'provided',
#   'live',
#   'score',
#   'coverage',
#   'tuesdayâ\x80\x99s',
#   'match',
#   'bayern',
#   'munich',
#   'salzburg',
#   '2nd',
#   'leg',
#   'uefa',
#   'champion',
#   'league',
#   'round',
#   '16'],
#  ['spur',
#   'hit',
#   'fresh',
#   'covid19',
#   'outbreak',
#   'ahead',
#   'league',
#   'cup',
#   'semi',
#   'tottenham',
#   'hit',
#   'fresh',
#   'coronavirus',
#   'concern',
#   'ahead',
#   'league',
#   'cup',
#   'semifinal',
#   'first',
#   'leg',
#   'chelsea',
#   'wednesday'],
#  ['comedy',
#   'play',
#   'abou',
#   'kabsoula',
#   'return',
#   'alexandria',
#   'cairo',
#   'run',
#   'show',
#   'staged',
#   'cairo',
#   'two',
#   'week',
#   'hit',
#   'first',
#   'run',
#   'star',
#   'young',
#   'comedian',
#   'mostafa',
#   'abosriea',
#   'directed',
#   'mohamed',
#   'morsi'],
#  ['italy',
#   'reserve',
#   'beat',
#   'wale',
#   '10',
#   'euro',
#   '2020',
#   'victory',
#   'extended',
#   'italy',
#   'unbeaten',
#   'streak',
#   '30',
#   'match',
#   'matching',
#   'team',
#   'record'],
#  ['shiyu', 'trading', 'quality', 'selection', 'service'],
#  ['egyptian',
#   'short',
#   'tuktuk',
#   'henet',
#   'ward',
#   'participate',
#   'pan',
#   'african',
#   'film',
#   'festival',
#   'los',
#   'angeles',
#   'paffâ\x80\x99s',
#   '29th',
#   'edition',
#   'scheduled',
#   'take',
#   'place',
#   'online',
#   '28',
#   'february',
#   '14',
#   'march',
#   '2021',
#   'u'],
#  ['backed',
#   'corner',
#   'egypt',
#   'independent',
#   'culture',
#   'five',
#   'year',
#   'revolution',
#   'revolution',
#   'triggered',
#   'profusion',
#   'artistic',
#   'expression',
#   'opened',
#   'vigorous',
#   'struggle',
#   'independent',
#   'culture',
#   'player',
#   'power',
#   'today',
#   'creator',
#   'find',
#   'alternative',
#   'refuge'],
#  ['cavani',
#   'extends',
#   'man',
#   'utd',
#   'contract',
#   '2022',
#   '34yearold',
#   'uruguayan',
#   'scored',
#   '15',
#   'goal',
#   'first',
#   'season',
#   'england'],
#  ['egypt',
#   'market',
#   'loss',
#   'accelerate',
#   'bank',
#   'raise',
#   'interest',
#   'rate'],
#  ['national',
#   'bank',
#   'egypt',
#   'subsidiary',
#   'say',
#   'drop',
#   'bid',
#   'buy',
#   'ci',
#   'capital'],
#  ['taken', 'decision', 'leave', 'atletico', 'griezmann'],
#  ['elsewedy',
#   'electric',
#   'sign',
#   'egp',
#   '12',
#   'bln',
#   'contract',
#   'consortium',
#   'upgrade',
#   'cairo',
#   'regional',
#   'centre',
#   'project',
#   'total',
#   'value',
#   'worth',
#   'egp',
#   '12',
#   'billion',
#   'egytechs',
#   'share',
#   'estimated',
#   'egp',
#   '5837',
#   'million'],
#  ['egyptian',
#   'filmmaker',
#   'marianne',
#   'khoury',
#   'awarded',
#   'france',
#   'legion',
#   'honor',
#   'producer',
#   'director',
#   'marianne',
#   'khoury',
#   'awarded',
#   'france',
#   'legion',
#   'honor',
#   'degree',
#   'chevalier',
#   'knight'],
#  ['u', 'company', 'china', 'say', 'theyve', 'hurt', 'trade', 'war'],
#  ['beyonce',
#   'jlo',
#   'headline',
#   'london',
#   'charity',
#   'concert',
#   'woman',
#   'beyonce',
#   'timbaland',
#   'ellie',
#   'goulding',
#   'jlo',
#   'among',
#   'starlist',
#   '1',
#   'june',
#   'sound',
#   'change',
#   'live',
#   'concert',
#   'fund',
#   'international',
#   'project',
#   'girl',
#   'woman'],
#  ['egypt',
#   'hend',
#   'elfalafly',
#   'hold',
#   'first',
#   'solo',
#   'exhibition',
#   'dubai',
#   'seven',
#   'sin',
#   'exhibition',
#   'hend',
#   'elfalafly',
#   'prize',
#   'winner',
#   'egypt',
#   'salon',
#   'young',
#   'artist',
#   '2011',
#   'open',
#   'dubai',
#   'art',
#   'sawa',
#   '16',
#   'december'],
#  ['var',
#   'operate',
#   'nyon',
#   'sevilla',
#   'v',
#   'chelsea',
#   'champion',
#   'league',
#   'game'],
#  ['egypt', 'observer', 'opec', 'meeting', 'vienna'],
#  ['turkey', 'cd', 'jump', 'highest', 'since', 'midjuly', 'moody', 'downgrade'],
#  ['egypt',
#   'targeting',
#   '8',
#   'percent',
#   'growth',
#   'fiscal',
#   'year',
#   '202122',
#   'prime',
#   'minister'],
#  ['chelsea', 'board', 'supported', 'lampard', 'say', 'gerrard'],
#  ['egyptian',
#   'writer',
#   'novel',
#   'appears',
#   'french',
#   'theatre',
#   'french',
#   'director',
#   'jean',
#   'martinelli',
#   'present',
#   'adaptation',
#   'alaswany',
#   'bestseller',
#   'chicago'],
#  ['tottenhams', 'bale', 'towards', 'end', 'career', 'admits', 'agent'],
#  ['swiss', 'actor', 'bruno', 'ganz', 'star', 'downfall', 'dy', '77'],
#  ['egyptian',
#   'actor',
#   'mahmoud',
#   'masoud',
#   'dy',
#   '67',
#   'born',
#   '1952',
#   'masoud',
#   'acted',
#   'score',
#   'work',
#   'renowned',
#   'egyptian',
#   'director'],
#  ['google',
#   'doodle',
#   'celebrates',
#   'birthday',
#   'egyptianborn',
#   'singer',
#   'dalida'],
#  ['syrian',
#   'documentary',
#   'sugar',
#   'cage',
#   'win',
#   '22nd',
#   'ismailia',
#   'intâ\x80\x99l',
#   'film',
#   'festival',
#   'challenging',
#   'edition',
#   'concluded',
#   'tuesday',
#   'dozen',
#   'documentary',
#   'short',
#   'film',
#   'competed',
#   'various',
#   'competition'],
#  ['fair', 'foul', 'shakespeare', 'many', 'guise', 'edinburgh', 'festival'],
#  ['egyptian',
#   'court',
#   'overturn',
#   'steel',
#   'tycoon',
#   'ahmed',
#   'ezzs',
#   '37year',
#   'sentence',
#   'steel',
#   'tycoon',
#   'face',
#   'retrial',
#   'charge',
#   'profiteering',
#   'squandering',
#   'public',
#   'fund'],
#  ['german', 'airline', 'cancel', 'flight', 'egypt', 'sharm', 'elsheikh'],
#  ['manchester',
#   'cityâ\x80\x99s',
#   'injured',
#   'jesus',
#   'ruled',
#   'brazil',
#   'qualifier'],
#  ['west',
#   'ham',
#   'coach',
#   'moyes',
#   'two',
#   'player',
#   'test',
#   'positive',
#   'covid19'],
#  ['match',
#   'fact',
#   'valencia',
#   'v',
#   'manchester',
#   'united',
#   'uefa',
#   'champion',
#   'league',
#   'ahram',
#   'online',
#   'provided',
#   'live',
#   'score',
#   'coverage',
#   'wednesday',
#   'match',
#   'valencia',
#   'manchester',
#   'united',
#   '6th',
#   'matchday',
#   'uefa',
#   'champion',
#   'league'],
#  ['pulisic', 'face', 'tough', 'task', 'breaking', 'chelsea'],
#  ['qatar', 'raise', 'game', 'fend', 'next', 'lng', 'giant'],
#  ['art',
#   'alert',
#   'contemporary',
#   'music',
#   'ensemble',
#   'perform',
#   'american',
#   'university',
#   'cairo',
#   'egyptian',
#   'contemporary',
#   'music',
#   'ensemble',
#   'present',
#   'classical',
#   'music',
#   'concert',
#   'contemporary',
#   'work',
#   'han',
#   'werner',
#   'henze',
#   'american',
#   'university',
#   'cairo',
#   '13',
#   'february'],
#  ['work',
#   'resume',
#   'tuesday',
#   'nile',
#   'company',
#   'road',
#   'demand',
#   'met',
#   'ahram',
#   'online',
#   'visit',
#   'striker',
#   'stateowned',
#   'nile',
#   'company',
#   'road',
#   'bridge',
#   'end',
#   'management',
#   'agrees',
#   'pay',
#   'rise',
#   'demand'],
#  ['minya',
#   'finding',
#   'way',
#   'using',
#   'waste',
#   'minya',
#   'governorate',
#   'taking',
#   'major',
#   'step',
#   'process',
#   'solid',
#   'waste',
#   'fuel',
#   'product'],
#  ['egyptian', 'pound', 'broadly', 'steady', 'moody', 'review'],
#  ['egypt',
#   'nominates',
#   'mohamed',
#   'diabs',
#   'clash',
#   '2017',
#   'academy',
#   'award',
#   'oscar',
#   'foreign',
#   'language',
#   'film',
#   'award',
#   'committee',
#   'select',
#   'final',
#   'film',
#   'compete',
#   'next',
#   'year',
#   'competition'],
#  ['minister',
#   'almashat',
#   'usaid',
#   'mission',
#   'director',
#   'discus',
#   'egyptus',
#   'cooperation',
#   '2025',
#   'meeting',
#   'reed',
#   'expressed',
#   'appreciation',
#   'egyptian',
#   'government',
#   'effort',
#   'pushing',
#   'towards',
#   'sustainable',
#   'recovery'],
#  ['celebrity',
#   'raise',
#   'fund',
#   'australian',
#   'bushfires',
#   'victim',
#   'please',
#   'donate',
#   'many',
#   'actor',
#   'pop',
#   'star',
#   'joined',
#   'fund',
#   'raising',
#   'campaign',
#   'victim',
#   'australia',
#   'fire'],
#  ['36th',
#   'cairo',
#   'international',
#   'film',
#   'festival',
#   'iranian',
#   'film',
#   'melbourne',
#   'win',
#   'best',
#   'film',
#   'closing',
#   'ceremony',
#   'giza',
#   'plateau',
#   'announces',
#   'award',
#   'prize',
#   'best',
#   'film',
#   'given',
#   'iranian',
#   'film',
#   'melbourne',
#   'khaled',
#   'abol',
#   'naga',
#   'egypt',
#   'best',
#   'actor',
#   'role',
#   'eye',
#   'thief',
#   'adã¨le',
#   'haenel',
#   'france',
#   'best',
#   'actress'],
#  ['saudi',
#   'consortium',
#   'end',
#   'bid',
#   'newcastle',
#   'longer',
#   'commercially',
#   'viable'],
#  ['luxor',
#   'african',
#   'film',
#   'festival',
#   'announces',
#   'winner',
#   '11th',
#   'edition',
#   'winner',
#   '11th',
#   'luxor',
#   'african',
#   'film',
#   'festival',
#   'laff',
#   'announced',
#   'festivalâ\x80\x99s',
#   'closing',
#   'ceremony',
#   '10',
#   'march'],
#  ['sudan',
#   'qatar',
#   'sign',
#   '4',
#   'bln',
#   'deal',
#   'manage',
#   'red',
#   'sea',
#   'port',
#   'ministry'],
#  ['werder',
#   'bremen',
#   'coach',
#   'accused',
#   'using',
#   'fake',
#   'vaccine',
#   'document',
#   'werder',
#   'bremen',
#   'say',
#   'coach',
#   'markus',
#   'anfang',
#   'investigation',
#   'german',
#   'authority',
#   'allegedly',
#   'using',
#   'fake',
#   'certificate',
#   'vaccination',
#   'coronavirus'],
#  ['egypt',
#   'main',
#   'index',
#   'start',
#   'november',
#   'green',
#   'rally',
#   'continues',
#   'sunday',
#   'buoyed',
#   'telecom',
#   'construction',
#   'real',
# ...
#   'stateowned',
#   'bangladesh',
#   'petroleum',
#   'corporation',
#   'finalises',
#   'deal',
#   'receive',
#   'oil',
#   'product',
#   'current',
#   'premium',
#   'excluding',
#   'fuel',
#   'oil'],
#  ['call',
#   'participation',
#   'interactive',
#   'audio',
#   'game',
#   'egypt',
#   'mawgat',
#   'intl',
#   'audio',
#   'drama',
#   'festival',
#   'established',
#   'orient',
#   'production',
#   'studio',
#   'emad',
#   'eddin',
#   'foundation',
#   'festival',
#   'invite',
#   'listener',
#   'interact',
#   'sharing',
#   'track'],
#  ['oil', 'fall', '37', 'near', '11year', 'low', 'excess', 'supply', 'weighs'],
#  ['new',
#   'york',
#   'metropolitan',
#   'opera',
#   'new',
#   'season',
#   'live',
#   'stream',
#   'egypt',
#   'met',
#   'opera',
#   'live',
#   'hd',
#   'transmission',
#   'started',
#   'streaming',
#   'egypt',
#   '2010'],
#  ['relentless', 'real', 'almost', 'touch', 'title', 'eighth', 'win', 'row'],
#  ['ancelotti', 'want', 'everton', 'aim', 'europe'],
#  ['iranian',
#   'artist',
#   'reza',
#   'derakshani',
#   'hold',
#   'solo',
#   'exhibit',
#   'new',
#   'york',
#   'gallery',
#   'silence',
#   'night',
#   'solo',
#   'exhibition',
#   'artist',
#   'reza',
#   'derakshani',
#   'featuring',
#   '10',
#   'sand',
#   'painting',
#   'installation',
#   'open',
#   '6',
#   'september',
#   'leila',
#   'heller',
#   'gallery',
#   'new',
#   'york'],
#  ['tennis',
#   'everything',
#   'possible',
#   'djokovic',
#   'eye',
#   'golden',
#   'grand',
#   'slam',
#   'world',
#   'number',
#   'one',
#   'captured',
#   'second',
#   'french',
#   'open',
#   '19th',
#   'slam',
#   '67',
#   '68',
#   '26',
#   '63',
#   '62',
#   '64',
#   'win',
#   'greece',
#   'stefanos',
#   'tsitsipas',
#   'sunday'],
#  ['sting', 'donates', 'prestigious', 'prize', 'money', 'refugee'],
#  ['dollar', 'weakens', 'u', 'data', 'disappoints'],
#  ['china',
#   'give',
#   'microsoft',
#   '20',
#   'day',
#   'provide',
#   'explanation',
#   'antitrust',
#   'probe',
#   'microsoft',
#   'one',
#   'least',
#   '30',
#   'foreign',
#   'company',
#   'scrutiny',
#   'china',
#   'regulator',
#   'government',
#   'seek',
#   'enforce',
#   'sixyear',
#   'old',
#   'antitrust',
#   'law'],
#  ['woody',
#   'allen',
#   'brush',
#   'rape',
#   'joke',
#   'sex',
#   'abuse',
#   'claim',
#   'cannes'],
#  ['egypt',
#   'internet',
#   'user',
#   'reached',
#   '36',
#   'million',
#   'june',
#   '2013',
#   'mcit',
#   'mobile',
#   'subscription',
#   '968',
#   'million',
#   'landline',
#   'penetration',
#   'declined',
#   '85'],
#  ['fifth',
#   '2b',
#   'continued',
#   'festival',
#   'spotlight',
#   'egyptâ\x80\x99s',
#   'promising',
#   'performing',
#   'art',
#   'scene',
#   'fifth',
#   'edition',
#   '2b',
#   'continued',
#   'festival',
#   'brought',
#   'strong',
#   'dance',
#   'theatre',
#   'performance',
#   'falaki',
#   'theatre',
#   'january'],
#  ['two',
#   'egyptian',
#   'film',
#   'released',
#   'online',
#   'filmstreaming',
#   'service',
#   'filmatique',
#   'nadine',
#   'khan',
#   'harag',
#   'w',
#   'marag',
#   'chaos',
#   'disorder',
#   'hala',
#   'lotfys',
#   'coming',
#   'forth',
#   'day',
#   'released',
#   'filmatique',
#   '8',
#   '15',
#   'december',
#   'making',
#   'available',
#   'viewer',
#   'united',
#   'state'],
#  ['egypt',
#   'economic',
#   'summit',
#   'scheduled',
#   '13',
#   'march',
#   'pm',
#   'egypt',
#   'announces',
#   'date',
#   'economic',
#   'summit',
#   'aimed',
#   'attracting',
#   'investment',
#   'country',
#   'imf',
#   'sends',
#   'assessment',
#   'delegation'],
#  ['martinez', 'cracker', 'help', 'colombia', 'past', 'argentina'],
#  ['egyptian',
#   'businessman',
#   'released',
#   'bail',
#   'returning',
#   'stolen',
#   'fund',
#   'wheat',
#   'corruption',
#   'scandal',
#   'official',
#   'wheat',
#   'procurement',
#   'sector',
#   'accused',
#   'stealing',
#   'egp',
#   '533',
#   'million',
#   'state',
#   'fund'],
#  ['bp', 'quarterly', 'profit', 'collapse', 'tumbling', 'oil', 'price'],
#  ['man', 'united', 'appoint', 'solskjaer', 'caretaker', 'manager'],
#  ['egyptian',
#   'film',
#   'bullet',
#   'bread',
#   'among',
#   'winner',
#   'red',
#   'sea',
#   'intl',
#   'film',
#   'festival',
#   'production',
#   'grant',
#   'film',
#   'directed',
#   'egyptian',
#   'filmmaker',
#   'mohammad',
#   'hammad',
#   'produced',
#   'kholoud',
#   'saad',
#   'mohamed',
#   'hefzy'],
#  ['egyptian',
#   'donkey',
#   'sculpture',
#   'travel',
#   'malta',
#   'mdina',
#   'cathedral',
#   'contemporary',
#   'art',
#   'biennale',
#   'year',
#   'biennale',
#   'themed',
#   'christianity',
#   'spirituality'],
#  ['match',
#   'fact',
#   'salzburg',
#   'v',
#   'bayern',
#   'munich',
#   'uefa',
#   'champion',
#   'league',
#   'ahram',
#   'online',
#   'provided',
#   'live',
#   'score',
#   'coverage',
#   'wednesdayâ\x80\x99s',
#   'match',
#   'salzburg',
#   'bayern',
#   'munich',
#   'first',
#   'leg',
#   'round',
#   '16',
#   'uefa',
#   'champion',
#   'league'],
#  ['let',
#   'flow',
#   'referee',
#   'praised',
#   'euro',
#   '2020',
#   'officiating',
#   'fewer',
#   'foul',
#   'booking',
#   'player',
#   'spent',
#   'time',
#   'ball',
#   'play',
#   'group',
#   'stage',
#   'official',
#   'data',
#   'shown'],
#  ['egypt', 'liberalises', 'custom', 'dollar', 'imported', 'commodity'],
#  ['evil',
#   'win',
#   'golden',
#   'bear',
#   'berlin',
#   'film',
#   'festival',
#   'iranian',
#   'director',
#   'mohammad',
#   'rasoulofs',
#   'win',
#   'prize',
#   'berlin',
#   'festival',
#   'absentia'],
#  ['egypt', 'pm', 'expects', 'imf', 'loan', 'signed', 'within', 'two', 'month'],
#  ['cairo',
#   'studio',
#   'emad',
#   'eddin',
#   'launch',
#   'online',
#   'dance',
#   'theatre',
#   'workshop',
#   'three',
#   'planned',
#   'workshop',
#   'cover',
#   'dance',
#   'acting',
#   'principle',
#   'costume',
#   'design'],
#  ['u', 'try', 'roman', 'polanski', 'arrested', 'poland'],
#  ['minister',
#   'almashat',
#   'discus',
#   'socioeconomic',
#   'impact',
#   'covid19',
#   'egypt'],
#  ['pianist',
#   'ramzi',
#   'yassa',
#   'play',
#   'manials',
#   'prince',
#   'mohamed',
#   'ali',
#   'palace',
#   'renowned',
#   'egyptian',
#   'pianist',
#   'perform',
#   'four',
#   'beethoven',
#   'sonata',
#   'palace',
#   'golden',
#   'hall',
#   'sunday',
#   '15',
#   'january'],
#  ['apple', 'take', 'netflix', '5amonth', 'streaming', 'service'],
#  ['ubers', 'middle', 'east', 'business', 'careem', 'cut', '31', 'workforce'],
#  ['environment',
#   'life',
#   'exhibition',
#   'nile',
#   'diplomatic',
#   'club',
#   'environmental',
#   'issue',
#   'lie',
#   'heart',
#   'many',
#   'pressing',
#   'developmental',
#   'concern',
#   'egypt',
#   'currently',
#   'face',
#   'prompting',
#   'nile',
#   'diplomatic',
#   'club',
#   'present',
#   'environment',
#   'life',
#   'exhibition'],
#  ['egyptâ\x80\x99s',
#   'payment',
#   'balance',
#   'ran',
#   '4109',
#   'mln',
#   'total',
#   'surplus',
#   '1h',
#   'fy20192020',
#   'central',
#   'bank',
#   'also',
#   'reported',
#   'investment',
#   'income',
#   'deficit',
#   'widened',
#   '58',
#   'billion'],
#  ['fitch',
#   'warns',
#   'may',
#   'cut',
#   'u',
#   'credit',
#   'rating',
#   'aaa',
#   'fitch',
#   'rating',
#   'say',
#   'could',
#   'cut',
#   'sovereign',
#   'credit',
#   'rating',
#   'united',
#   'state',
#   'debt',
#   'limit',
#   'raised',
#   'time',
#   'firm',
#   'take',
#   'final',
#   'decision',
#   'end',
#   '2014',
#   'first',
#   'quarter'],
#  ['republished',
#   'coming',
#   'forth',
#   'day',
#   'portrait',
#   'pain',
#   'first',
#   'local',
#   'showcase',
#   'arthouse',
#   'cinema',
#   'initiative',
#   'zawya',
#   'egyptian',
#   'director',
#   'hala',
#   'lotfys',
#   'coming',
#   'forth',
#   'day',
#   'screening',
#   'odeon',
#   'cinema',
#   'starting',
#   'wednesday',
#   '30',
#   'april'],
#  ['alexandria',
#   'film',
#   'festival',
#   'mediterranean',
#   'country',
#   'come',
#   'close',
#   'closing',
#   'ceremony',
#   'take',
#   'place',
#   'monday',
#   '15',
#   'september',
#   'alexandria',
#   'library'],
#  ['egypt',
#   'sign',
#   'deal',
#   'france',
#   'engie',
#   'lng',
#   'import',
#   'renewable',
#   'energy',
#   'development'],
#  ['lost', 'treasure', 'syria', 'palmyra', 'rise', 'new', '3d', 'show'],
#  ['sheikh',
#   'jackson',
#   'photocopy',
#   'egypt',
#   'strong',
#   'presence',
#   'new',
#   'york',
#   'arab',
#   'cinema',
#   'week',
#   'several',
#   'egyptian',
#   'film',
#   'screened',
#   'ongoing',
#   'new',
#   'york',
#   'arab',
#   'cinema',
#   'week',
#   'sheikh',
#   'jackson',
#   'photocopy',
#   'featured',
#   'opening',
#   'closing',
#   'night',
#   'respectively'],
#  ['egyptâ\x80\x99s',
#   'targeted',
#   'growth',
#   'lowered',
#   '42',
#   'public',
#   'debt',
#   'increased',
#   'egp',
#   '44',
#   'bln',
#   'amid',
#   'coronavirus',
#   'crisis',
#   'finance',
#   'minister'],
#  ['guendouzi', 'surprised', 'instant', 'impact', 'arsenal'],
#  ['british', 'tabloid', 'sorry', 'george', 'clooney', 'wedding', 'story'],
#  ['lebanon',
#   'central',
#   'bank',
#   'approves',
#   'efg',
#   'hermes',
#   'sale',
#   'credit',
#   'libanais',
#   'stake'],
#  ['egyptian',
#   'parliamentary',
#   'committee',
#   'approves',
#   '12',
#   'billion',
#   'imf',
#   'loan',
#   'law',
#   'move',
#   'forward',
#   'vote',
#   'plenary',
#   'session'],
#  ['bayern',
#   'player',
#   'lead',
#   'shortlist',
#   'seasonending',
#   'champion',
#   'league',
#   'award'],
#  ['42nd',
#   'cairo',
#   'intl',
#   'film',
#   'festival',
#   'unveils',
#   'jury',
#   'member',
#   'jury',
#   'festival',
#   'upcoming',
#   'edition',
#   'scheduled',
#   '210',
#   'december',
#   'feature',
#   '22',
#   'filmmaker',
#   'across',
#   '16',
#   'country'],
#  ['french',
#   'conductor',
#   'lead',
#   'tehran',
#   'orchestra',
#   'sign',
#   'growing',
#   'tie'],
#  ['english',
#   'premier',
#   'league',
#   'result',
#   'scorer',
#   '11th',
#   'matchday',
#   'follow',
#   'ahram',
#   'onlines',
#   'coverage',
#   'english',
#   'premier',
#   'league',
#   'match',
#   '35',
#   'november'],
#  ['dubaiâ\x80\x99s',
#   'expo',
#   '2020',
#   'host',
#   'virtual',
#   'meeting',
#   'participant',
#   'steering',
#   'committee',
#   'discussing',
#   'covid19',
#   'impact'],
#  ['star', 'trek', 'star', 'leonard', 'nimoy', 'dead', '83', 'u', 'medium'],
#  ['egypt',
#   'cargo',
#   'village',
#   'saw',
#   '10',
#   'rise',
#   'custom',
#   'revenue',
#   '2013',
#   'higher',
#   'volume',
#   'import',
#   'increased',
#   'collection',
#   'fine',
#   'led',
#   'growth',
#   'revenue',
#   'egypt',
#   'custom',
#   'cargo',
#   'village',
#   '2013'],
#  ['benfica', 'deny', 'report', 'costa', 'signing'],
#  ['75', 'winner', 'nobel', 'economics', 'prize', 'still', 'contentious'],
#  ['czech',
#   'move',
#   'euro',
#   'base',
#   'camp',
#   'home',
#   'strict',
#   'scotland',
#   'rule'],
#  ['emirate', 'agrees', '425', 'mn', 'loan', 'two', 'a380', 'jet', 'bank'],
#  ['corruption',
#   'egypt',
#   'remains',
#   'high',
#   'transparency',
#   'international',
#   'egypt',
#   'score',
#   '32',
#   'corruption',
#   'scale',
#   'demonstrating',
#   'lack',
#   'seriousness',
#   'tackling',
#   'corruption',
#   'say',
#   'transparency',
#   'international'],
#  ['oscar',
#   'winner',
#   'american',
#   'actor',
#   'william',
#   'hurt',
#   'dy',
#   '71',
#   'william',
#   'hurt',
#   'whose',
#   'laconic',
#   'charisma',
#   'selfassured',
#   'subtlety',
#   'actor',
#   'made',
#   'one',
#   '1980s',
#   'foremost',
#   'leading',
#   'men',
#   'movie',
#   'broadcast',
#   'news',
#   'body',
#   'heat',
#   'big',
#   'chill',
#   'died',
#   '71'],
#  ['match',
#   'fact',
#   'barcelona',
#   'v',
#   'tottenham',
#   'hotspur',
#   'uefa',
#   'champion',
#   'league',
#   'ahram',
#   'online',
#   'provided',
#   'live',
#   'score',
#   'coverage',
#   'tuesday',
#   'match',
#   'barcelona',
#   'tottenham',
#   'hotspur',
#   '6th',
#   'matchday',
#   'uefa',
#   'champion',
#   'league'],
#  ['beltone',
#   'sawiris',
#   'others',
#   'seek',
#   'stake',
#   'egypt',
#   'efg',
#   'hermes',
#   'source',
#   'group',
#   'investor',
#   'include',
#   'naguib',
#   'sawiris',
#   'offer',
#   '224',
#   'per',
#   'share',
#   'stake',
#   'egypt',
#   'efghermes',
#   'investment',
#   'bank',
#   'said',
#   'source'],
#  ['swiss', 'approve', 'dissolution', 'scandalhit', 'bank', 'bsi'],
#  ['iraq', 'war', 'turn', 'upcoming', 'new', 'york', 'musical', 'baghdaddy'],
#  ['bayerns', 'boateng', 'doubtful', 'start', 'bundesliga', 'season'],
#  ['egyptian', 'team', 'visit', 'russia', 'discus', 'trade', 'tension'],
#  ['benzema',
#   'handed',
#   '1year',
#   'suspended',
#   'sentence',
#   'blackmail',
#   'case',
#   'france',
#   'real',
#   'madrid',
#   'forward',
#   'karim',
#   'benzema',
#   'given',
#   '1year',
#   'suspended',
#   'jail',
#   'sentence',
#   '75000',
#   'euro',
#   '84000',
#   'fine',
#   'wednesday',
#   'sex',
#   'tape',
#   'case',
#   'rocked',
#   'french',
#   'soccer'],
#  ['tribute',
#   'abdalla',
#   'gohar',
#   '1',
#   'december',
#   'khan',
#   'al',
#   'maghraby',
#   'open',
#   'exhibition',
#   'presenting',
#   'work',
#   'abdalla',
#   'gohar'],
#  ['match',
#   'fact',
#   'rb',
#   'leipzig',
#   'v',
#   'psg',
#   'uefa',
#   'champion',
#   'league',
#   'ahram',
#   'online',
#   'provided',
#   'live',
#   'score',
#   'coverage',
#   'tuesdayâ\x80\x99s',
#   'match',
#   'rb',
#   'leipzig',
#   'paris',
#   'saintgermain',
#   'semifinal',
#   'uefa',
#   'champion',
#   'league'],
#  ['graffiti', 'art', 'paris', 'tell', 'story', 'refugee', 'fleeing', 'video'],
#  ['egypt',
#   'finalise',
#   '20',
#   'oil',
#   'gas',
#   'concession',
#   'year',
#   'end',
#   'minister',
#   'twenty',
#   'deal',
#   'work',
#   'say',
#   'egypt',
#   'petroleum',
#   'minister',
#   'country',
#   'aim',
#   'tackle',
#   'growing',
#   'energy',
#   'crisis'],
#  ['preview',
#   'man',
#   'city',
#   'chelsea',
#   'eye',
#   'champion',
#   'league',
#   'glory',
#   'porto',
#   'final',
#   'third',
#   'final',
#   'europe',
#   'elite',
#   'club',
#   'competition',
#   'played',
#   'two',
#   'premier',
#   'league',
#   'side'],
#  ['german', 'export', 'collapse', 'april', 'coronavirus', 'wreck', 'demand'],
#  ['flamenco',
#   'fingertip',
#   'seminar',
#   'series',
#   'performance',
#   'straight',
#   'spain',
#   'el',
#   'namla',
#   'spanish',
#   'embassy',
#   'bring',
#   'cairo',
#   'wellrounded',
#   'package',
#   'flamenco',
#   'seminar',
#   'guitar',
#   'course',
#   'starting',
#   'today',
#   'performance',
#   'schedule',
#   'listed'],
#  ['art',
#   'alert',
#   'sayed',
#   'darwish',
#   'song',
#   'auc',
#   'band',
#   'nesma',
#   'mahgoub',
#   'eskendrella',
#   'bibliotheca',
#   'alexandrina',
#   'host',
#   'concert',
#   'celebrates',
#   'centennial',
#   '1919',
#   'revolution'],
#  ['student',
#   'egypt',
#   'aldarb',
#   'alahmar',
#   'school',
#   'talk',
#   'art',
#   'education',
#   'life',
#   'change',
#   'joining',
#   'aldarb',
#   'alahmar',
#   'art',
#   'school',
#   'student',
#   '2010',
#   'hosseini',
#   'mohamed',
#   'gained',
#   'array',
#   'artistic',
#   'skill',
#   'range',
#   'performing',
#   'circus',
#   'act',
#   'playing',
#   'different',
#   'musical',
#   'instrument'],
#  ['film',
#   'review',
#   'karma',
#   'offer',
#   'familiar',
#   'story',
#   'social',
#   'contrast',
#   'captivating',
#   'twist',
#   'entangled',
#   'storyline',
#   'khaled',
#   'youssefs',
#   'film',
#   'karma',
#   'offer',
#   'fresh',
#   'take',
#   'old',
#   'trope',
#   'prince',
#   'pauper'],
#  ['egyptian',
#   'artist',
#   'exhibit',
#   'work',
#   'germany',
#   'egyptian',
#   'visual',
#   'artist',
#   'taha',
#   'hussein',
#   'show',
#   'four',
#   'artwork',
#   'collective',
#   'exhibition',
#   'germany'],
#  ['egypt',
#   'boosting',
#   'economic',
#   'growth',
#   'rate',
#   'woman',
#   'role',
#   'minister',
#   'davos',
#   'egypt',
#   'eager',
#   'participation',
#   'private',
#   'sector',
#   'achieving',
#   'sustainable',
#   'development',
#   'key',
#   'engine',
#   'egyptâ\x80\x99s',
#   'economic',
#   'growth',
#   'said',
#   'elmashat'],
#  ['art',
#   'alert',
#   'six',
#   'day',
#   'contemporary',
#   'dance',
#   'cairoâ\x80\x99s',
#   'jesuit',
#   'center',
#   'platform',
#   'collection',
#   '3',
#   'dance',
#   'performance',
#   'cairo',
#   'contemporary',
#   'dance',
#   'companyâ\x80\x99s',
#   'professional',
#   'training',
#   'program'],
#  ['ensemble',
#   'bokra',
#   'egypt',
#   'new',
#   'formation',
#   'big',
#   'plan',
#   'ahead',
#   'ensemble',
#   'bokras',
#   'friday',
#   '21',
#   'feb',
#   'inaugural',
#   'concert',
#   'bahaa',
#   'elansary',
#   'dynamo',
#   'behind',
#   'fresh',
#   'creation',
#   'reveals',
#   'hope',
#   'infuse',
#   'music',
#   'field',
#   'new',
#   'spirit'],
#  ['egypt',
#   'issue',
#   'longestterm',
#   'international',
#   'bond',
#   'maturity',
#   '40',
#   'year'],
#  ['cbe',
#   'waif',
#   'egp',
#   '485',
#   'bln',
#   'installed',
#   'enterprise',
#   'factory',
#   'debt',
#   'meeting',
#   'held',
#   'past',
#   'week',
#   '176',
#   'enterprise',
#   'resulted',
#   'dropping',
#   'legal',
#   'case',
#   '91',
#   'company'],
#  ['renowned',
#   'egyptian',
#   'filmmaker',
#   'khairy',
#   'beshara',
#   'cinema',
#   'life',
#   'soundcloud',
#   'podcast',
#   'beshara',
#   'reveals',
#   'detail',
#   'film',
#   'currently',
#   'preparing',
#   'strong',
#   'connection',
#   'china'],
#  ['german',
#   'sport',
#   'facing',
#   'disruption',
#   '4th',
#   'coronavirus',
#   'wave',
#   'hit',
#   'canceled',
#   'game',
#   'player',
#   'quarantine',
#   'argument',
#   'vaccine',
#   'mandate'],
#  ...]

# %%
#Tf-Idf
tfidf_vectorizer = TfidfVectorizer(use_idf=True)
X_train_vectors_tfidf = tfidf_vectorizer.fit_transform(X_train) 
X_test_vectors_tfidf = tfidf_vectorizer.transform(X_test)

# %%
#FITTING THE CLASSIFICATION MODEL using Logistic Regression(tf-idf)
lr_tfidf=LogisticRegression(solver = 'liblinear', C=10, penalty = 'l2')
lr_tfidf.fit(X_train_vectors_tfidf, y_train)  
#Predict y value for test dataset
y_predict = lr_tfidf.predict(X_test_vectors_tfidf)
y_prob = lr_tfidf.predict_proba(X_test_vectors_tfidf)[:,1]
print(classification_report(y_test,y_predict))
print('Confusion Matrix: \n',confusion_matrix(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#          Art       0.99      0.99      0.99      2043
#      economy       0.99      0.99      0.99      2008
#       sports       0.99      0.99      0.99      2037
#
#     accuracy                           0.99      6088
#    macro avg       0.99      0.99      0.99      6088
# weighted avg       0.99      0.99      0.99      6088
#
# Confusion Matrix:
#  [[2023   10   10]
#  [  11 1993    4]
#  [  10   12 2015]]

# %%
#FITTING THE CLASSIFICATION MODEL using Naive Bayes(tf-idf)
nb_tfidf = MultinomialNB()
nb_tfidf.fit(X_train_vectors_tfidf, y_train)  
#Predict y value for test dataset
y_predict = nb_tfidf.predict(X_test_vectors_tfidf)
y_prob = nb_tfidf.predict_proba(X_test_vectors_tfidf)[:,1]
print(classification_report(y_test,y_predict))
print('Confusion Matrix: \n',confusion_matrix(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#          Art       0.99      0.98      0.99      2043
#      economy       0.98      0.99      0.99      2008
#       sports       0.99      0.99      0.99      2037
#
#     accuracy                           0.99      6088
#    macro avg       0.99      0.99      0.99      6088
# weighted avg       0.99      0.99      0.99      6088
#
# Confusion Matrix:
#  [[2011   20   12]
#  [  17 1990    1]
#  [   9   15 2013]]

# %%
df_test = pd.DataFrame(X_test)
df_test
# Out:
#                                               Final_Text
# 20264  eu provides â¬3 billion fund egyptâs water ...
# 4661   programmetrailers 5th cairo video festival med...
# 14762      telecom egypt see 107pct jump net profit 2015
# 9168                  saudi artist seen pushing boundary
# 5437   egyptian director yousry nasrallah say idea ne...
# ...                                                  ...
# 11447  egypt stock rise wednesday despite cairo unive...
# 27980       one fa cup semi used test event return crowd
# 26554  neymar eclipse ronaldo peru hattrick brings 64...
# 16553  egypt plan establish free economic zone south ...
# 20848     isco asensio lead madrid copa del reys last 16
#
# [6088 rows x 1 columns]

# %%
#first step
import string
string.punctuation
from nltk.tokenize import word_tokenize

def remove_punctuation(text):
    punctuationfree="".join([i for i in text if i not in string.punctuation])
    return punctuationfree

stopwords = nltk.corpus.stopwords.words('english')
def remove_stopwords(text):
    output= [i for i in text if i not in stopwords]
    return output


# preporcessing new text input
def finalpreprocess(sentence):
    punc = remove_punctuation(sentence)
    #print(punc)
    low = punc.lower()
    #tokens = word_tokenize(low)
    #stops=remove_stopwords(low)
    vectors = tfidf_vectorizer.transform([low])
    return vectors

#test_user_input = finalpreprocess("iconic actor adel emam celebration birthday public")
#test_user_input = finalpreprocess("we won the match after they were losing 2-0, they end up winning very well")
test_user_input = finalpreprocess("UAE President issues Federal Law to maintain 2022 budget balance")

input_predict = lr_tfidf.predict(test_user_input)
prob = lr_tfidf.predict_proba(test_user_input)

print("Predicted Category is : ",(input_predict[0]),"\nWords Probabilties : ", prob)
labels=["Art","Economy","Sports"]
labels[np.argmax(prob)]
# Out:
# Predicted Category is :  economy
# Words Probabilties :  [[0.01779189 0.86018548 0.12202263]]
# 'Economy'

# %%
input_predict = (nb_tfidf.predict(test_user_input))
prob = nb_tfidf.predict_proba(test_user_input)[:,1]
print(input_predict[0])
# Out:
# economy
